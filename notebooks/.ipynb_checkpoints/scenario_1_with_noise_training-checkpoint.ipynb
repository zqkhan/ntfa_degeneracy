# %%
# %cd ../
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch

# %%
import logging
import numpy as np
import htfa_torch.dtfa as DTFA
import htfa_torch.niidb as niidb
import htfa_torch.utils as utils
import matplotlib.pyplot as plt
# Out:
# /home/zulqarnain/anaconda3/envs/htfatorch/lib/python3.7/site-packages/nilearn/datasets/__init__.py:89: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
import itertools
from torch.nn.functional import softplus
import matplotlib.patches as mpatches
from ordered_set import OrderedSet

# %%
import torch

# %%
# %matplotlib inline

# %%
logging.basicConfig(format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %H:%M:%S',
                    level=logging.INFO)

# %%
scenario = '1'
noise_factor = 2
num_subjects = 2
db_file = 'data/simulated_simplified_data_' + scenario + '_' + str(num_subjects)+ '_' + str(noise_factor) + '.db'
scenario_name = 'scenario_' + scenario + '_' + str(num_subjects)+ '_' + str(noise_factor)
TRAIN = True
synthetic_db = niidb.FMriActivationsDb(db_file)

# %%
dtfa = DTFA.DeepTFA(synthetic_db.all(), mask='/home/zulqarnain/fmri_data/simulated_degeneracy_data/wholebrain.nii.gz', num_factors=3, embedding_dim=2)
# Out:
# 10/08/2021 15:21:46 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video1_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:46 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video2_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:46 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video3_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:46 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video4_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:47 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video5_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:47 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video6_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:47 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video7_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:47 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_1_video8_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:47 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video1_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:47 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video2_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:47 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video3_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:48 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video4_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:48 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video5_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:48 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video6_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:48 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video7_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:21:48 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_1_subjects_2_10/nifti_files/participant_2_video8_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)

# %%
dtfa.num_blocks
# Out:
# 16

# %%
dtfa.tasks()
# Out:
# OrderedSet(['video1', 'video2', 'video3', 'video4', 'video5', 'video6', 'video7', 'video8'])

# %%
dtfa.subjects()
# Out:
# OrderedSet([1, 2])

# %%
dtfa.visualize_factor_embedding()
# Out:
# (<nilearn.plotting.displays.OrthoProjector at 0x7f7384e8ffd0>,
#  tensor([[-33.1512, -48.9445,   4.1909],
#          [  1.8936,  26.1729,  16.0403],
#          [ 33.3142, -50.3018,   3.4959]]),
#  tensor([7.3571, 7.2669, 7.3500]))

# %%
if TRAIN:
    losses = dtfa.train(num_steps=400, learning_rate={'q': 1e-1, 'p': 1e-3}, log_level=logging.INFO, num_particles=1,
                        batch_size=60, use_cuda=True, checkpoint_steps=500, blocks_batch_size=60, patience=50)
else:
    dtfa.load_state('data/scenario_1_subjects_2_2')
# Out:
# 10/08/2021 15:21:51 [Epoch 1] (438ms) Posterior free-energy 9.38196320e+07 = KL from prior 2.12955249e+03 - log-likelihood -9.38175040e+07
# 10/08/2021 15:21:51 Saving checkpoint...
# 10/08/2021 15:21:51 [Epoch 2] (184ms) Posterior free-energy 9.00770400e+07 = KL from prior 2.10629370e+03 - log-likelihood -9.00749360e+07
# 10/08/2021 15:21:51 [Epoch 3] (205ms) Posterior free-energy 8.78344080e+07 = KL from prior 2.13717651e+03 - log-likelihood -8.78322720e+07
# 10/08/2021 15:21:52 [Epoch 4] (205ms) Posterior free-energy 8.73462640e+07 = KL from prior 2.14104639e+03 - log-likelihood -8.73441200e+07
# 10/08/2021 15:21:52 [Epoch 5] (204ms) Posterior free-energy 8.56938880e+07 = KL from prior 2.17592139e+03 - log-likelihood -8.56917120e+07
# 10/08/2021 15:21:52 [Epoch 6] (205ms) Posterior free-energy 8.51819200e+07 = KL from prior 2.21600781e+03 - log-likelihood -8.51797040e+07
# 10/08/2021 15:21:52 [Epoch 7] (206ms) Posterior free-energy 8.43904480e+07 = KL from prior 2.25117017e+03 - log-likelihood -8.43882000e+07
# 10/08/2021 15:21:53 [Epoch 8] (209ms) Posterior free-energy 8.37878400e+07 = KL from prior 2.30319995e+03 - log-likelihood -8.37855360e+07
# 10/08/2021 15:21:53 [Epoch 9] (209ms) Posterior free-energy 8.35623120e+07 = KL from prior 2.37009985e+03 - log-likelihood -8.35599440e+07
# 10/08/2021 15:21:53 [Epoch 10] (208ms) Posterior free-energy 8.32780400e+07 = KL from prior 2.36029565e+03 - log-likelihood -8.32756800e+07
# 10/08/2021 15:21:53 [Epoch 11] (210ms) Posterior free-energy 8.31004080e+07 = KL from prior 2.37779956e+03 - log-likelihood -8.30980320e+07
# 10/08/2021 15:21:53 [Epoch 12] (209ms) Posterior free-energy 8.28899760e+07 = KL from prior 2.40864062e+03 - log-likelihood -8.28875680e+07
# 10/08/2021 15:21:54 [Epoch 13] (211ms) Posterior free-energy 8.27617760e+07 = KL from prior 2.42786719e+03 - log-likelihood -8.27593520e+07
# 10/08/2021 15:21:54 [Epoch 14] (211ms) Posterior free-energy 8.26405920e+07 = KL from prior 2.47180688e+03 - log-likelihood -8.26381200e+07
# 10/08/2021 15:21:54 [Epoch 15] (212ms) Posterior free-energy 8.25662000e+07 = KL from prior 2.49287378e+03 - log-likelihood -8.25637040e+07
# 10/08/2021 15:21:54 [Epoch 16] (211ms) Posterior free-energy 8.24900800e+07 = KL from prior 2.47143384e+03 - log-likelihood -8.24876080e+07
# 10/08/2021 15:21:54 [Epoch 17] (215ms) Posterior free-energy 8.24418480e+07 = KL from prior 2.51148267e+03 - log-likelihood -8.24393360e+07
# 10/08/2021 15:21:55 [Epoch 18] (213ms) Posterior free-energy 8.23699840e+07 = KL from prior 2.55617920e+03 - log-likelihood -8.23674240e+07
# 10/08/2021 15:21:55 [Epoch 19] (213ms) Posterior free-energy 8.23477680e+07 = KL from prior 2.60173877e+03 - log-likelihood -8.23451680e+07
# 10/08/2021 15:21:55 [Epoch 20] (214ms) Posterior free-energy 8.23174320e+07 = KL from prior 2.61518018e+03 - log-likelihood -8.23148160e+07
# 10/08/2021 15:21:55 [Epoch 21] (216ms) Posterior free-energy 8.22438320e+07 = KL from prior 2.65919312e+03 - log-likelihood -8.22411760e+07
# 10/08/2021 15:21:56 [Epoch 22] (215ms) Posterior free-energy 8.22077840e+07 = KL from prior 2.65677466e+03 - log-likelihood -8.22051280e+07
# 10/08/2021 15:21:56 [Epoch 23] (217ms) Posterior free-energy 8.22018480e+07 = KL from prior 2.66048413e+03 - log-likelihood -8.21991840e+07
# 10/08/2021 15:21:56 [Epoch 24] (228ms) Posterior free-energy 8.21940720e+07 = KL from prior 2.68780103e+03 - log-likelihood -8.21913840e+07
# 10/08/2021 15:21:56 [Epoch 25] (239ms) Posterior free-energy 8.21793840e+07 = KL from prior 2.67086938e+03 - log-likelihood -8.21767120e+07
# 10/08/2021 15:21:56 [Epoch 26] (235ms) Posterior free-energy 8.21408800e+07 = KL from prior 2.70104346e+03 - log-likelihood -8.21381760e+07
# 10/08/2021 15:21:57 [Epoch 27] (240ms) Posterior free-energy 8.21286960e+07 = KL from prior 2.71696899e+03 - log-likelihood -8.21259760e+07
# 10/08/2021 15:21:57 [Epoch 28] (234ms) Posterior free-energy 8.21219520e+07 = KL from prior 2.68185034e+03 - log-likelihood -8.21192720e+07
# 10/08/2021 15:21:57 [Epoch 29] (237ms) Posterior free-energy 8.21093760e+07 = KL from prior 2.68464966e+03 - log-likelihood -8.21066880e+07
# 10/08/2021 15:21:57 [Epoch 30] (322ms) Posterior free-energy 8.21077120e+07 = KL from prior 2.70342578e+03 - log-likelihood -8.21050080e+07
# 10/08/2021 15:21:58 [Epoch 31] (224ms) Posterior free-energy 8.20728320e+07 = KL from prior 2.73893823e+03 - log-likelihood -8.20700960e+07
# 10/08/2021 15:21:58 [Epoch 32] (233ms) Posterior free-energy 8.20885440e+07 = KL from prior 2.74530811e+03 - log-likelihood -8.20858000e+07
# 10/08/2021 15:21:58 [Epoch 33] (296ms) Posterior free-energy 8.20788800e+07 = KL from prior 2.73971777e+03 - log-likelihood -8.20761440e+07
# 10/08/2021 15:21:59 [Epoch 34] (274ms) Posterior free-energy 8.20748000e+07 = KL from prior 2.75464990e+03 - log-likelihood -8.20720480e+07
# 10/08/2021 15:21:59 [Epoch 35] (270ms) Posterior free-energy 8.20492960e+07 = KL from prior 2.75403833e+03 - log-likelihood -8.20465440e+07
# 10/08/2021 15:21:59 [Epoch 36] (265ms) Posterior free-energy 8.20530800e+07 = KL from prior 2.75070264e+03 - log-likelihood -8.20503280e+07
# 10/08/2021 15:21:59 [Epoch 37] (249ms) Posterior free-energy 8.20586000e+07 = KL from prior 2.74682495e+03 - log-likelihood -8.20558560e+07
# 10/08/2021 15:22:00 [Epoch 38] (279ms) Posterior free-energy 8.19883040e+07 = KL from prior 2.79186841e+03 - log-likelihood -8.19855120e+07
# 10/08/2021 15:22:00 [Epoch 39] (305ms) Posterior free-energy 8.20112480e+07 = KL from prior 2.78455420e+03 - log-likelihood -8.20084640e+07
# 10/08/2021 15:22:00 [Epoch 40] (290ms) Posterior free-energy 8.20423520e+07 = KL from prior 2.74536987e+03 - log-likelihood -8.20396080e+07
# 10/08/2021 15:22:00 [Epoch 41] (304ms) Posterior free-energy 8.20363840e+07 = KL from prior 2.76402612e+03 - log-likelihood -8.20336160e+07
# 10/08/2021 15:22:01 [Epoch 42] (305ms) Posterior free-energy 8.20462800e+07 = KL from prior 2.76848218e+03 - log-likelihood -8.20435120e+07
# 10/08/2021 15:22:01 [Epoch 43] (306ms) Posterior free-energy 8.19984800e+07 = KL from prior 2.76199927e+03 - log-likelihood -8.19957200e+07
# 10/08/2021 15:22:01 [Epoch 44] (302ms) Posterior free-energy 8.19719360e+07 = KL from prior 2.74102734e+03 - log-likelihood -8.19691920e+07
# 10/08/2021 15:22:02 [Epoch 45] (300ms) Posterior free-energy 8.20261680e+07 = KL from prior 2.80282324e+03 - log-likelihood -8.20233680e+07
# 10/08/2021 15:22:02 [Epoch 46] (346ms) Posterior free-energy 8.20307440e+07 = KL from prior 2.76369824e+03 - log-likelihood -8.20279840e+07
# 10/08/2021 15:22:02 [Epoch 47] (345ms) Posterior free-energy 8.19863840e+07 = KL from prior 2.74766406e+03 - log-likelihood -8.19836400e+07
# 10/08/2021 15:22:03 [Epoch 48] (360ms) Posterior free-energy 8.19363600e+07 = KL from prior 2.75905493e+03 - log-likelihood -8.19336000e+07
# 10/08/2021 15:22:03 [Epoch 49] (276ms) Posterior free-energy 8.19751760e+07 = KL from prior 2.78407812e+03 - log-likelihood -8.19723920e+07
# 10/08/2021 15:22:03 [Epoch 50] (360ms) Posterior free-energy 8.19875120e+07 = KL from prior 2.76117310e+03 - log-likelihood -8.19847520e+07
# 10/08/2021 15:22:04 [Epoch 51] (439ms) Posterior free-energy 8.19789760e+07 = KL from prior 2.77941772e+03 - log-likelihood -8.19762000e+07
# 10/08/2021 15:22:04 [Epoch 52] (399ms) Posterior free-energy 8.19718560e+07 = KL from prior 2.78530737e+03 - log-likelihood -8.19690720e+07
# 10/08/2021 15:22:05 [Epoch 53] (310ms) Posterior free-energy 8.20040400e+07 = KL from prior 2.77379956e+03 - log-likelihood -8.20012640e+07
# 10/08/2021 15:22:05 [Epoch 54] (337ms) Posterior free-energy 8.19942240e+07 = KL from prior 2.74876587e+03 - log-likelihood -8.19914720e+07
# 10/08/2021 15:22:05 [Epoch 55] (340ms) Posterior free-energy 8.19430480e+07 = KL from prior 2.75334106e+03 - log-likelihood -8.19402960e+07
# 10/08/2021 15:22:06 [Epoch 56] (341ms) Posterior free-energy 8.19308800e+07 = KL from prior 2.74400806e+03 - log-likelihood -8.19281360e+07
# 10/08/2021 15:22:06 [Epoch 57] (330ms) Posterior free-energy 8.19375840e+07 = KL from prior 2.76649341e+03 - log-likelihood -8.19348160e+07
# 10/08/2021 15:22:06 [Epoch 58] (341ms) Posterior free-energy 8.19559680e+07 = KL from prior 2.75859863e+03 - log-likelihood -8.19532080e+07
# 10/08/2021 15:22:07 [Epoch 59] (349ms) Posterior free-energy 8.19040880e+07 = KL from prior 2.73107568e+03 - log-likelihood -8.19013600e+07
# 10/08/2021 15:22:07 [Epoch 60] (355ms) Posterior free-energy 8.19982320e+07 = KL from prior 2.74796509e+03 - log-likelihood -8.19954880e+07
# 10/08/2021 15:22:07 [Epoch 61] (401ms) Posterior free-energy 8.19737120e+07 = KL from prior 2.76498730e+03 - log-likelihood -8.19709440e+07
# 10/08/2021 15:22:08 [Epoch 62] (335ms) Posterior free-energy 8.19465040e+07 = KL from prior 2.75336060e+03 - log-likelihood -8.19437520e+07
# 10/08/2021 15:22:08 [Epoch 63] (345ms) Posterior free-energy 8.19263920e+07 = KL from prior 2.73690405e+03 - log-likelihood -8.19236560e+07
# 10/08/2021 15:22:08 [Epoch 64] (339ms) Posterior free-energy 8.19517120e+07 = KL from prior 2.76479346e+03 - log-likelihood -8.19489440e+07
# 10/08/2021 15:22:09 [Epoch 65] (345ms) Posterior free-energy 8.19539200e+07 = KL from prior 2.72280322e+03 - log-likelihood -8.19512000e+07
# 10/08/2021 15:22:09 [Epoch 66] (355ms) Posterior free-energy 8.18961920e+07 = KL from prior 2.73759180e+03 - log-likelihood -8.18934560e+07
# 10/08/2021 15:22:09 [Epoch 67] (414ms) Posterior free-energy 8.19015200e+07 = KL from prior 2.73184473e+03 - log-likelihood -8.18987920e+07
# 10/08/2021 15:22:10 [Epoch 68] (387ms) Posterior free-energy 8.18540480e+07 = KL from prior 2.72564380e+03 - log-likelihood -8.18513200e+07
# 10/08/2021 15:22:10 [Epoch 69] (367ms) Posterior free-energy 8.19668720e+07 = KL from prior 2.68216089e+03 - log-likelihood -8.19641920e+07
# 10/08/2021 15:22:11 [Epoch 70] (438ms) Posterior free-energy 8.19022320e+07 = KL from prior 2.70876636e+03 - log-likelihood -8.18995200e+07
# 10/08/2021 15:22:11 [Epoch 71] (445ms) Posterior free-energy 8.18532640e+07 = KL from prior 2.74972949e+03 - log-likelihood -8.18505120e+07
# 10/08/2021 15:22:12 [Epoch 72] (412ms) Posterior free-energy 8.18765120e+07 = KL from prior 2.69234644e+03 - log-likelihood -8.18738160e+07
# 10/08/2021 15:22:12 [Epoch 73] (396ms) Posterior free-energy 8.18713040e+07 = KL from prior 2.71033105e+03 - log-likelihood -8.18685920e+07
# 10/08/2021 15:22:12 [Epoch 74] (466ms) Posterior free-energy 8.18691280e+07 = KL from prior 2.71323438e+03 - log-likelihood -8.18664160e+07
# 10/08/2021 15:22:13 [Epoch 75] (425ms) Posterior free-energy 8.18835280e+07 = KL from prior 2.68013257e+03 - log-likelihood -8.18808480e+07
# 10/08/2021 15:22:13 [Epoch 76] (405ms) Posterior free-energy 8.19471840e+07 = KL from prior 2.66270215e+03 - log-likelihood -8.19445200e+07
# 10/08/2021 15:22:14 [Epoch 77] (401ms) Posterior free-energy 8.17655680e+07 = KL from prior 2.73819849e+03 - log-likelihood -8.17628320e+07
# 10/08/2021 15:22:14 [Epoch 78] (401ms) Posterior free-energy 8.18059920e+07 = KL from prior 2.71278955e+03 - log-likelihood -8.18032800e+07
# 10/08/2021 15:22:14 [Epoch 79] (382ms) Posterior free-energy 8.18878720e+07 = KL from prior 2.71974512e+03 - log-likelihood -8.18851520e+07
# 10/08/2021 15:22:15 [Epoch 80] (422ms) Posterior free-energy 8.18908960e+07 = KL from prior 2.67238257e+03 - log-likelihood -8.18882240e+07
# 10/08/2021 15:22:15 [Epoch 81] (430ms) Posterior free-energy 8.18627840e+07 = KL from prior 2.70001367e+03 - log-likelihood -8.18600800e+07
# 10/08/2021 15:22:16 [Epoch 82] (416ms) Posterior free-energy 8.19218080e+07 = KL from prior 2.69185400e+03 - log-likelihood -8.19191200e+07
# 10/08/2021 15:22:16 [Epoch 83] (497ms) Posterior free-energy 8.18167120e+07 = KL from prior 2.68728394e+03 - log-likelihood -8.18140240e+07
# 10/08/2021 15:22:17 [Epoch 84] (488ms) Posterior free-energy 8.18685280e+07 = KL from prior 2.64261768e+03 - log-likelihood -8.18658880e+07
# 10/08/2021 15:22:17 [Epoch 85] (513ms) Posterior free-energy 8.17645120e+07 = KL from prior 2.68446387e+03 - log-likelihood -8.17618240e+07
# 10/08/2021 15:22:18 [Epoch 86] (497ms) Posterior free-energy 8.18218000e+07 = KL from prior 2.67754858e+03 - log-likelihood -8.18191200e+07
# 10/08/2021 15:22:18 [Epoch 87] (484ms) Posterior free-energy 8.17651600e+07 = KL from prior 2.64419238e+03 - log-likelihood -8.17625120e+07
# 10/08/2021 15:22:19 [Epoch 88] (552ms) Posterior free-energy 8.18999520e+07 = KL from prior 2.64228711e+03 - log-likelihood -8.18973120e+07
# 10/08/2021 15:22:19 [Epoch 89] (535ms) Posterior free-energy 8.18472080e+07 = KL from prior 2.66377710e+03 - log-likelihood -8.18445440e+07
# 10/08/2021 15:22:20 [Epoch 90] (599ms) Posterior free-energy 8.18531920e+07 = KL from prior 2.72002979e+03 - log-likelihood -8.18504720e+07
# 10/08/2021 15:22:21 [Epoch 91] (977ms) Posterior free-energy 8.18994000e+07 = KL from prior 2.62106445e+03 - log-likelihood -8.18967760e+07
# 10/08/2021 15:22:22 [Epoch 92] (874ms) Posterior free-energy 8.18256320e+07 = KL from prior 2.68425708e+03 - log-likelihood -8.18229440e+07
# 10/08/2021 15:22:22 [Epoch 93] (675ms) Posterior free-energy 8.18665280e+07 = KL from prior 2.64318481e+03 - log-likelihood -8.18638880e+07
# 10/08/2021 15:22:23 [Epoch 94] (602ms) Posterior free-energy 8.18319360e+07 = KL from prior 2.62300610e+03 - log-likelihood -8.18293120e+07
# 10/08/2021 15:22:24 [Epoch 95] (538ms) Posterior free-energy 8.17475360e+07 = KL from prior 2.65118384e+03 - log-likelihood -8.17448880e+07
# 10/08/2021 15:22:24 [Epoch 96] (484ms) Posterior free-energy 8.17836880e+07 = KL from prior 2.64201538e+03 - log-likelihood -8.17810480e+07
# 10/08/2021 15:22:25 [Epoch 97] (500ms) Posterior free-energy 8.19078080e+07 = KL from prior 2.61779224e+03 - log-likelihood -8.19051920e+07
# 10/08/2021 15:22:25 [Epoch 98] (457ms) Posterior free-energy 8.17265760e+07 = KL from prior 2.60948462e+03 - log-likelihood -8.17239680e+07
# 10/08/2021 15:22:25 [Epoch 99] (412ms) Posterior free-energy 8.18628480e+07 = KL from prior 2.59299414e+03 - log-likelihood -8.18602560e+07
# 10/08/2021 15:22:26 [Epoch 100] (467ms) Posterior free-energy 8.17924160e+07 = KL from prior 2.58348779e+03 - log-likelihood -8.17898320e+07
# 10/08/2021 15:22:26 [Epoch 101] (487ms) Posterior free-energy 8.17465520e+07 = KL from prior 2.62760132e+03 - log-likelihood -8.17439280e+07
# 10/08/2021 15:22:27 [Epoch 102] (517ms) Posterior free-energy 8.17714480e+07 = KL from prior 2.58832642e+03 - log-likelihood -8.17688560e+07
# 10/08/2021 15:22:27 [Epoch 103] (433ms) Posterior free-energy 8.17302000e+07 = KL from prior 2.61015234e+03 - log-likelihood -8.17275920e+07
# 10/08/2021 15:22:28 [Epoch 104] (477ms) Posterior free-energy 8.17632480e+07 = KL from prior 2.62198511e+03 - log-likelihood -8.17606240e+07
# 10/08/2021 15:22:28 [Epoch 105] (477ms) Posterior free-energy 8.17395760e+07 = KL from prior 2.62962598e+03 - log-likelihood -8.17369440e+07
# 10/08/2021 15:22:29 [Epoch 106] (474ms) Posterior free-energy 8.18161600e+07 = KL from prior 2.59378882e+03 - log-likelihood -8.18135680e+07
# 10/08/2021 15:22:29 [Epoch 107] (406ms) Posterior free-energy 8.16936720e+07 = KL from prior 2.59222827e+03 - log-likelihood -8.16910800e+07
# 10/08/2021 15:22:30 [Epoch 108] (441ms) Posterior free-energy 8.17814400e+07 = KL from prior 2.62552515e+03 - log-likelihood -8.17788160e+07
# 10/08/2021 15:22:30 [Epoch 109] (515ms) Posterior free-energy 8.17393440e+07 = KL from prior 2.59017261e+03 - log-likelihood -8.17367520e+07
# 10/08/2021 15:22:31 [Epoch 110] (487ms) Posterior free-energy 8.16737120e+07 = KL from prior 2.57188794e+03 - log-likelihood -8.16711440e+07
# 10/08/2021 15:22:31 [Epoch 111] (460ms) Posterior free-energy 8.17440480e+07 = KL from prior 2.63614404e+03 - log-likelihood -8.17414080e+07
# 10/08/2021 15:22:32 [Epoch 112] (428ms) Posterior free-energy 8.18715200e+07 = KL from prior 2.63264551e+03 - log-likelihood -8.18688880e+07
# 10/08/2021 15:22:32 [Epoch 113] (460ms) Posterior free-energy 8.16799360e+07 = KL from prior 2.57539819e+03 - log-likelihood -8.16773600e+07
# 10/08/2021 15:22:32 [Epoch 114] (484ms) Posterior free-energy 8.18078720e+07 = KL from prior 2.60654419e+03 - log-likelihood -8.18052640e+07
# 10/08/2021 15:22:33 [Epoch 115] (473ms) Posterior free-energy 8.17475520e+07 = KL from prior 2.59266455e+03 - log-likelihood -8.17449600e+07
# 10/08/2021 15:22:33 [Epoch 116] (432ms) Posterior free-energy 8.17861120e+07 = KL from prior 2.65828564e+03 - log-likelihood -8.17834560e+07
# 10/08/2021 15:22:34 [Epoch 117] (463ms) Posterior free-energy 8.16989920e+07 = KL from prior 2.58110278e+03 - log-likelihood -8.16964080e+07
# 10/08/2021 15:22:34 [Epoch 118] (481ms) Posterior free-energy 8.17003200e+07 = KL from prior 2.55265845e+03 - log-likelihood -8.16977680e+07
# 10/08/2021 15:22:35 [Epoch 119] (469ms) Posterior free-energy 8.17873200e+07 = KL from prior 2.58912158e+03 - log-likelihood -8.17847280e+07
# 10/08/2021 15:22:35 [Epoch 120] (424ms) Posterior free-energy 8.16725920e+07 = KL from prior 2.58389136e+03 - log-likelihood -8.16700080e+07
# 10/08/2021 15:22:36 [Epoch 121] (448ms) Posterior free-energy 8.16204400e+07 = KL from prior 2.59991699e+03 - log-likelihood -8.16178400e+07
# 10/08/2021 15:22:36 [Epoch 122] (525ms) Posterior free-energy 8.16799280e+07 = KL from prior 2.53534766e+03 - log-likelihood -8.16773920e+07
# 10/08/2021 15:22:37 [Epoch 123] (470ms) Posterior free-energy 8.16543920e+07 = KL from prior 2.57311865e+03 - log-likelihood -8.16518160e+07
# 10/08/2021 15:22:37 [Epoch 124] (434ms) Posterior free-energy 8.16594640e+07 = KL from prior 2.58604761e+03 - log-likelihood -8.16568800e+07
# 10/08/2021 15:22:38 [Epoch 125] (405ms) Posterior free-energy 8.16966560e+07 = KL from prior 2.62174268e+03 - log-likelihood -8.16940320e+07
# 10/08/2021 15:22:38 [Epoch 126] (456ms) Posterior free-energy 8.17301200e+07 = KL from prior 2.54129980e+03 - log-likelihood -8.17275760e+07
# 10/08/2021 15:22:38 [Epoch 127] (462ms) Posterior free-energy 8.16128320e+07 = KL from prior 2.57030322e+03 - log-likelihood -8.16102640e+07
# 10/08/2021 15:22:39 [Epoch 128] (474ms) Posterior free-energy 8.16750320e+07 = KL from prior 2.56365649e+03 - log-likelihood -8.16724720e+07
# 10/08/2021 15:22:39 [Epoch 129] (386ms) Posterior free-energy 8.16105520e+07 = KL from prior 2.53255640e+03 - log-likelihood -8.16080160e+07
# 10/08/2021 15:22:40 [Epoch 130] (422ms) Posterior free-energy 8.17060080e+07 = KL from prior 2.54800708e+03 - log-likelihood -8.17034560e+07
# 10/08/2021 15:22:40 [Epoch 131] (484ms) Posterior free-energy 8.16511200e+07 = KL from prior 2.57566699e+03 - log-likelihood -8.16485440e+07
# 10/08/2021 15:22:41 [Epoch 132] (492ms) Posterior free-energy 8.16732480e+07 = KL from prior 2.55068481e+03 - log-likelihood -8.16706960e+07
# 10/08/2021 15:22:41 [Epoch 133] (419ms) Posterior free-energy 8.16178880e+07 = KL from prior 2.57609399e+03 - log-likelihood -8.16153120e+07
# 10/08/2021 15:22:42 [Epoch 134] (456ms) Posterior free-energy 8.14987760e+07 = KL from prior 2.56162695e+03 - log-likelihood -8.14962160e+07
# 10/08/2021 15:22:42 [Epoch 135] (460ms) Posterior free-energy 8.16366080e+07 = KL from prior 2.54646484e+03 - log-likelihood -8.16340640e+07
# 10/08/2021 15:22:43 [Epoch 136] (479ms) Posterior free-energy 8.15798880e+07 = KL from prior 2.51940527e+03 - log-likelihood -8.15773680e+07
# 10/08/2021 15:22:43 [Epoch 137] (499ms) Posterior free-energy 8.15283440e+07 = KL from prior 2.51305835e+03 - log-likelihood -8.15258320e+07
# 10/08/2021 15:22:44 [Epoch 138] (488ms) Posterior free-energy 8.16439840e+07 = KL from prior 2.53971265e+03 - log-likelihood -8.16414480e+07
# 10/08/2021 15:22:44 [Epoch 139] (489ms) Posterior free-energy 8.15548560e+07 = KL from prior 2.53418750e+03 - log-likelihood -8.15523200e+07
# 10/08/2021 15:22:44 [Epoch 140] (462ms) Posterior free-energy 8.16246160e+07 = KL from prior 2.46785083e+03 - log-likelihood -8.16221520e+07
# 10/08/2021 15:22:45 [Epoch 141] (470ms) Posterior free-energy 8.14943600e+07 = KL from prior 2.50311035e+03 - log-likelihood -8.14918560e+07
# 10/08/2021 15:22:45 [Epoch 142] (485ms) Posterior free-energy 8.14995600e+07 = KL from prior 2.46080591e+03 - log-likelihood -8.14970960e+07
# 10/08/2021 15:22:46 [Epoch 143] (467ms) Posterior free-energy 8.15542320e+07 = KL from prior 2.49320166e+03 - log-likelihood -8.15517360e+07
# 10/08/2021 15:22:46 [Epoch 144] (465ms) Posterior free-energy 8.14904160e+07 = KL from prior 2.51404224e+03 - log-likelihood -8.14879040e+07
# 10/08/2021 15:22:47 [Epoch 145] (420ms) Posterior free-energy 8.15894560e+07 = KL from prior 2.46072607e+03 - log-likelihood -8.15869920e+07
# 10/08/2021 15:22:47 [Epoch 146] (470ms) Posterior free-energy 8.15011200e+07 = KL from prior 2.41485962e+03 - log-likelihood -8.14987040e+07
# 10/08/2021 15:22:48 [Epoch 147] (467ms) Posterior free-energy 8.14448720e+07 = KL from prior 2.47263892e+03 - log-likelihood -8.14424000e+07
# 10/08/2021 15:22:48 [Epoch 148] (454ms) Posterior free-energy 8.14789600e+07 = KL from prior 2.43906299e+03 - log-likelihood -8.14765200e+07
# 10/08/2021 15:22:49 [Epoch 149] (405ms) Posterior free-energy 8.14743120e+07 = KL from prior 2.44099316e+03 - log-likelihood -8.14718720e+07
# 10/08/2021 15:22:49 [Epoch 150] (474ms) Posterior free-energy 8.14645520e+07 = KL from prior 2.41069824e+03 - log-likelihood -8.14621440e+07
# 10/08/2021 15:22:50 [Epoch 151] (456ms) Posterior free-energy 8.14773840e+07 = KL from prior 2.40034058e+03 - log-likelihood -8.14749840e+07
# 10/08/2021 15:22:50 [Epoch 152] (439ms) Posterior free-energy 8.14859840e+07 = KL from prior 2.36616650e+03 - log-likelihood -8.14836160e+07
# 10/08/2021 15:22:50 [Epoch 153] (420ms) Posterior free-energy 8.15013600e+07 = KL from prior 2.38412036e+03 - log-likelihood -8.14989760e+07
# 10/08/2021 15:22:51 [Epoch 154] (423ms) Posterior free-energy 8.14857360e+07 = KL from prior 2.35733350e+03 - log-likelihood -8.14833760e+07
# 10/08/2021 15:22:51 [Epoch 155] (485ms) Posterior free-energy 8.14642400e+07 = KL from prior 2.36600317e+03 - log-likelihood -8.14618720e+07
# 10/08/2021 15:22:52 [Epoch 156] (482ms) Posterior free-energy 8.14457440e+07 = KL from prior 2.38243677e+03 - log-likelihood -8.14433600e+07
# 10/08/2021 15:22:52 [Epoch 157] (476ms) Posterior free-energy 8.14259760e+07 = KL from prior 2.37889429e+03 - log-likelihood -8.14236000e+07
# 10/08/2021 15:22:53 [Epoch 158] (503ms) Posterior free-energy 8.14441280e+07 = KL from prior 2.32248877e+03 - log-likelihood -8.14418080e+07
# 10/08/2021 15:22:53 [Epoch 159] (451ms) Posterior free-energy 8.14396720e+07 = KL from prior 2.33165479e+03 - log-likelihood -8.14373440e+07
# 10/08/2021 15:22:54 [Epoch 160] (432ms) Posterior free-energy 8.14508560e+07 = KL from prior 2.29925024e+03 - log-likelihood -8.14485600e+07
# 10/08/2021 15:22:54 [Epoch 161] (459ms) Posterior free-energy 8.13914960e+07 = KL from prior 2.32354956e+03 - log-likelihood -8.13891760e+07
# 10/08/2021 15:22:55 [Epoch 162] (501ms) Posterior free-energy 8.13572160e+07 = KL from prior 2.29484961e+03 - log-likelihood -8.13549200e+07
# 10/08/2021 15:22:55 [Epoch 163] (449ms) Posterior free-energy 8.13728560e+07 = KL from prior 2.32585498e+03 - log-likelihood -8.13705280e+07
# 10/08/2021 15:22:55 [Epoch 164] (444ms) Posterior free-energy 8.13831120e+07 = KL from prior 2.28892480e+03 - log-likelihood -8.13808240e+07
# 10/08/2021 15:22:56 [Epoch 165] (458ms) Posterior free-energy 8.13387520e+07 = KL from prior 2.31972388e+03 - log-likelihood -8.13364320e+07
# 10/08/2021 15:22:56 [Epoch 166] (478ms) Posterior free-energy 8.13146880e+07 = KL from prior 2.26668140e+03 - log-likelihood -8.13124240e+07
# 10/08/2021 15:22:57 [Epoch 167] (479ms) Posterior free-energy 8.13468880e+07 = KL from prior 2.27536768e+03 - log-likelihood -8.13446160e+07
# 10/08/2021 15:22:57 [Epoch 168] (487ms) Posterior free-energy 8.13192560e+07 = KL from prior 2.24040283e+03 - log-likelihood -8.13170160e+07
# 10/08/2021 15:22:58 [Epoch 169] (492ms) Posterior free-energy 8.13731280e+07 = KL from prior 2.25046191e+03 - log-likelihood -8.13708800e+07
# 10/08/2021 15:22:58 [Epoch 170] (468ms) Posterior free-energy 8.12992160e+07 = KL from prior 2.22972510e+03 - log-likelihood -8.12969840e+07
# 10/08/2021 15:22:59 [Epoch 171] (474ms) Posterior free-energy 8.12940160e+07 = KL from prior 2.24657446e+03 - log-likelihood -8.12917680e+07
# 10/08/2021 15:22:59 [Epoch 172] (496ms) Posterior free-energy 8.12935120e+07 = KL from prior 2.17041138e+03 - log-likelihood -8.12913440e+07
# 10/08/2021 15:23:00 [Epoch 173] (543ms) Posterior free-energy 8.12877680e+07 = KL from prior 2.22990039e+03 - log-likelihood -8.12855360e+07
# 10/08/2021 15:23:01 [Epoch 174] (674ms) Posterior free-energy 8.13024560e+07 = KL from prior 2.18376099e+03 - log-likelihood -8.13002720e+07
# 10/08/2021 15:23:01 [Epoch 175] (576ms) Posterior free-energy 8.12373840e+07 = KL from prior 2.17758521e+03 - log-likelihood -8.12352080e+07
# 10/08/2021 15:23:02 [Epoch 176] (540ms) Posterior free-energy 8.12396080e+07 = KL from prior 2.16737646e+03 - log-likelihood -8.12374400e+07
# 10/08/2021 15:23:02 [Epoch 177] (481ms) Posterior free-energy 8.12442320e+07 = KL from prior 2.20524463e+03 - log-likelihood -8.12420240e+07
# 10/08/2021 15:23:03 [Epoch 178] (508ms) Posterior free-energy 8.12174720e+07 = KL from prior 2.18307178e+03 - log-likelihood -8.12152880e+07
# 10/08/2021 15:23:03 [Epoch 179] (451ms) Posterior free-energy 8.12265920e+07 = KL from prior 2.19303906e+03 - log-likelihood -8.12244000e+07
# 10/08/2021 15:23:04 [Epoch 180] (414ms) Posterior free-energy 8.12425440e+07 = KL from prior 2.11810840e+03 - log-likelihood -8.12404240e+07
# 10/08/2021 15:23:04 [Epoch 181] (453ms) Posterior free-energy 8.12166160e+07 = KL from prior 2.11084644e+03 - log-likelihood -8.12145040e+07
# 10/08/2021 15:23:04 [Epoch 182] (470ms) Posterior free-energy 8.11715040e+07 = KL from prior 2.06506909e+03 - log-likelihood -8.11694400e+07
# 10/08/2021 15:23:05 [Epoch 183] (457ms) Posterior free-energy 8.11970720e+07 = KL from prior 2.09891333e+03 - log-likelihood -8.11949760e+07
# 10/08/2021 15:23:05 [Epoch 184] (425ms) Posterior free-energy 8.11936960e+07 = KL from prior 2.04137573e+03 - log-likelihood -8.11916560e+07
# 10/08/2021 15:23:06 [Epoch 185] (427ms) Posterior free-energy 8.11791360e+07 = KL from prior 2.06758618e+03 - log-likelihood -8.11770720e+07
# 10/08/2021 15:23:06 [Epoch 186] (500ms) Posterior free-energy 8.11622480e+07 = KL from prior 2.04701624e+03 - log-likelihood -8.11602000e+07
# 10/08/2021 15:23:07 [Epoch 187] (508ms) Posterior free-energy 8.11665120e+07 = KL from prior 2.06915454e+03 - log-likelihood -8.11644400e+07
# 10/08/2021 15:23:07 [Epoch 188] (411ms) Posterior free-energy 8.11677440e+07 = KL from prior 2.02707983e+03 - log-likelihood -8.11657200e+07
# 10/08/2021 15:23:08 [Epoch 189] (419ms) Posterior free-energy 8.11321920e+07 = KL from prior 2.00302295e+03 - log-likelihood -8.11301920e+07
# 10/08/2021 15:23:08 [Epoch 190] (471ms) Posterior free-energy 8.11350000e+07 = KL from prior 2.00743921e+03 - log-likelihood -8.11329920e+07
# 10/08/2021 15:23:09 [Epoch 191] (489ms) Posterior free-energy 8.11104880e+07 = KL from prior 1.97312878e+03 - log-likelihood -8.11085120e+07
# 10/08/2021 15:23:09 [Epoch 192] (440ms) Posterior free-energy 8.11130960e+07 = KL from prior 1.91165991e+03 - log-likelihood -8.11111840e+07
# 10/08/2021 15:23:10 [Epoch 193] (494ms) Posterior free-energy 8.10857360e+07 = KL from prior 1.90808032e+03 - log-likelihood -8.10838240e+07
# 10/08/2021 15:23:10 [Epoch 194] (456ms) Posterior free-energy 8.10946720e+07 = KL from prior 1.87171265e+03 - log-likelihood -8.10928000e+07
# 10/08/2021 15:23:10 [Epoch 195] (460ms) Posterior free-energy 8.11010480e+07 = KL from prior 1.92128271e+03 - log-likelihood -8.10991280e+07
# 10/08/2021 15:23:11 [Epoch 196] (457ms) Posterior free-energy 8.10791760e+07 = KL from prior 1.89850549e+03 - log-likelihood -8.10772800e+07
# 10/08/2021 15:23:11 [Epoch 197] (459ms) Posterior free-energy 8.10816080e+07 = KL from prior 1.86000439e+03 - log-likelihood -8.10797440e+07
# 10/08/2021 15:23:12 [Epoch 198] (492ms) Posterior free-energy 8.10698960e+07 = KL from prior 1.88260339e+03 - log-likelihood -8.10680160e+07
# 10/08/2021 15:23:12 [Epoch 199] (490ms) Posterior free-energy 8.10598320e+07 = KL from prior 1.86664746e+03 - log-likelihood -8.10579680e+07
# 10/08/2021 15:23:13 [Epoch 200] (477ms) Posterior free-energy 8.10447120e+07 = KL from prior 1.86682178e+03 - log-likelihood -8.10428480e+07
# 10/08/2021 15:23:13 [Epoch 201] (483ms) Posterior free-energy 8.10341680e+07 = KL from prior 1.85607385e+03 - log-likelihood -8.10323120e+07
# 10/08/2021 15:23:14 [Epoch 202] (506ms) Posterior free-energy 8.10319920e+07 = KL from prior 1.82867651e+03 - log-likelihood -8.10301600e+07
# 10/08/2021 15:23:15 [Epoch 203] (736ms) Posterior free-energy 8.10328640e+07 = KL from prior 1.83742859e+03 - log-likelihood -8.10310240e+07
# 10/08/2021 15:23:15 [Epoch 204] (587ms) Posterior free-energy 8.10165600e+07 = KL from prior 1.84368823e+03 - log-likelihood -8.10147200e+07
# 10/08/2021 15:23:16 [Epoch 205] (583ms) Posterior free-energy 8.10106080e+07 = KL from prior 1.79952295e+03 - log-likelihood -8.10088080e+07
# 10/08/2021 15:23:16 [Epoch 206] (491ms) Posterior free-energy 8.09893360e+07 = KL from prior 1.82396167e+03 - log-likelihood -8.09875120e+07
# 10/08/2021 15:23:17 [Epoch 207] (499ms) Posterior free-energy 8.10185760e+07 = KL from prior 1.77557703e+03 - log-likelihood -8.10168000e+07
# 10/08/2021 15:23:17 [Epoch 208] (461ms) Posterior free-energy 8.10062880e+07 = KL from prior 1.80989917e+03 - log-likelihood -8.10044800e+07
# 10/08/2021 15:23:18 [Epoch 209] (467ms) Posterior free-energy 8.09938480e+07 = KL from prior 1.76060510e+03 - log-likelihood -8.09920880e+07
# 10/08/2021 15:23:18 [Epoch 210] (487ms) Posterior free-energy 8.10031600e+07 = KL from prior 1.78169116e+03 - log-likelihood -8.10013760e+07
# 10/08/2021 15:23:19 [Epoch 211] (486ms) Posterior free-energy 8.09878720e+07 = KL from prior 1.81489368e+03 - log-likelihood -8.09860560e+07
# 10/08/2021 15:23:19 [Epoch 212] (439ms) Posterior free-energy 8.09821360e+07 = KL from prior 1.73488232e+03 - log-likelihood -8.09804000e+07
# 10/08/2021 15:23:19 [Epoch 213] (424ms) Posterior free-energy 8.09681120e+07 = KL from prior 1.76163953e+03 - log-likelihood -8.09663520e+07
# 10/08/2021 15:23:20 [Epoch 214] (479ms) Posterior free-energy 8.09646080e+07 = KL from prior 1.74152075e+03 - log-likelihood -8.09628640e+07
# 10/08/2021 15:23:21 [Epoch 215] (533ms) Posterior free-energy 8.09644080e+07 = KL from prior 1.76645349e+03 - log-likelihood -8.09626400e+07
# 10/08/2021 15:23:21 [Epoch 216] (439ms) Posterior free-energy 8.09602480e+07 = KL from prior 1.68583923e+03 - log-likelihood -8.09585600e+07
# 10/08/2021 15:23:21 [Epoch 217] (424ms) Posterior free-energy 8.09421680e+07 = KL from prior 1.75028796e+03 - log-likelihood -8.09404160e+07
# 10/08/2021 15:23:22 [Epoch 218] (464ms) Posterior free-energy 8.09473680e+07 = KL from prior 1.74619360e+03 - log-likelihood -8.09456240e+07
# 10/08/2021 15:23:22 [Epoch 219] (527ms) Posterior free-energy 8.09467920e+07 = KL from prior 1.71802576e+03 - log-likelihood -8.09450720e+07
# 10/08/2021 15:23:23 [Epoch 220] (481ms) Posterior free-energy 8.09433440e+07 = KL from prior 1.73877588e+03 - log-likelihood -8.09416080e+07
# 10/08/2021 15:23:23 [Epoch 221] (441ms) Posterior free-energy 8.09309680e+07 = KL from prior 1.70205701e+03 - log-likelihood -8.09292640e+07
# 10/08/2021 15:23:24 [Epoch 222] (440ms) Posterior free-energy 8.09349920e+07 = KL from prior 1.72233105e+03 - log-likelihood -8.09332720e+07
# 10/08/2021 15:23:24 [Epoch 223] (450ms) Posterior free-energy 8.09278320e+07 = KL from prior 1.67059912e+03 - log-likelihood -8.09261600e+07
# 10/08/2021 15:23:25 [Epoch 224] (455ms) Posterior free-energy 8.09247680e+07 = KL from prior 1.67256006e+03 - log-likelihood -8.09230960e+07
# 10/08/2021 15:23:25 [Epoch 225] (460ms) Posterior free-energy 8.09184720e+07 = KL from prior 1.69227429e+03 - log-likelihood -8.09167760e+07
# 10/08/2021 15:23:26 [Epoch 226] (490ms) Posterior free-energy 8.09161280e+07 = KL from prior 1.65516602e+03 - log-likelihood -8.09144720e+07
# 10/08/2021 15:23:26 [Epoch 227] (448ms) Posterior free-energy 8.09154880e+07 = KL from prior 1.71907800e+03 - log-likelihood -8.09137680e+07
# 10/08/2021 15:23:26 [Epoch 228] (432ms) Posterior free-energy 8.09102640e+07 = KL from prior 1.65108203e+03 - log-likelihood -8.09086160e+07
# 10/08/2021 15:23:27 [Epoch 229] (450ms) Posterior free-energy 8.09035280e+07 = KL from prior 1.69399829e+03 - log-likelihood -8.09018320e+07
# 10/08/2021 15:23:27 [Epoch 230] (489ms) Posterior free-energy 8.09069120e+07 = KL from prior 1.66686597e+03 - log-likelihood -8.09052480e+07
# 10/08/2021 15:23:28 [Epoch 231] (490ms) Posterior free-energy 8.08989440e+07 = KL from prior 1.65484351e+03 - log-likelihood -8.08972880e+07
# 10/08/2021 15:23:28 [Epoch 232] (485ms) Posterior free-energy 8.08974640e+07 = KL from prior 1.63266663e+03 - log-likelihood -8.08958320e+07
# 10/08/2021 15:23:29 [Epoch 233] (504ms) Posterior free-energy 8.08945280e+07 = KL from prior 1.61269983e+03 - log-likelihood -8.08929120e+07
# 10/08/2021 15:23:29 [Epoch 234] (476ms) Posterior free-energy 8.08959680e+07 = KL from prior 1.62636780e+03 - log-likelihood -8.08943440e+07
# 10/08/2021 15:23:30 [Epoch 235] (469ms) Posterior free-energy 8.08905200e+07 = KL from prior 1.62229016e+03 - log-likelihood -8.08888960e+07
# 10/08/2021 15:23:30 [Epoch 236] (456ms) Posterior free-energy 8.08906720e+07 = KL from prior 1.61472437e+03 - log-likelihood -8.08890560e+07
# 10/08/2021 15:23:31 [Epoch 237] (431ms) Posterior free-energy 8.08873840e+07 = KL from prior 1.60430286e+03 - log-likelihood -8.08857760e+07
# 10/08/2021 15:23:31 [Epoch 238] (477ms) Posterior free-energy 8.08878880e+07 = KL from prior 1.61617639e+03 - log-likelihood -8.08862720e+07
# 10/08/2021 15:23:32 [Epoch 239] (482ms) Posterior free-energy 8.08858000e+07 = KL from prior 1.62478223e+03 - log-likelihood -8.08841760e+07
# 10/08/2021 15:23:32 [Epoch 240] (474ms) Posterior free-energy 8.08833840e+07 = KL from prior 1.63037488e+03 - log-likelihood -8.08817520e+07
# 10/08/2021 15:23:33 [Epoch 241] (506ms) Posterior free-energy 8.08801440e+07 = KL from prior 1.63515015e+03 - log-likelihood -8.08785120e+07
# 10/08/2021 15:23:33 [Epoch 242] (470ms) Posterior free-energy 8.08760400e+07 = KL from prior 1.61157922e+03 - log-likelihood -8.08744320e+07
# 10/08/2021 15:23:34 [Epoch 243] (529ms) Posterior free-energy 8.08768000e+07 = KL from prior 1.59219287e+03 - log-likelihood -8.08752080e+07
# 10/08/2021 15:23:34 [Epoch 244] (492ms) Posterior free-energy 8.08754320e+07 = KL from prior 1.59360010e+03 - log-likelihood -8.08738400e+07
# 10/08/2021 15:23:35 [Epoch 245] (459ms) Posterior free-energy 8.08763040e+07 = KL from prior 1.60580908e+03 - log-likelihood -8.08746960e+07
# 10/08/2021 15:23:35 [Epoch 246] (418ms) Posterior free-energy 8.08753360e+07 = KL from prior 1.59914514e+03 - log-likelihood -8.08737360e+07
# 10/08/2021 15:23:36 [Epoch 247] (438ms) Posterior free-energy 8.08746960e+07 = KL from prior 1.54949817e+03 - log-likelihood -8.08731440e+07
# 10/08/2021 15:23:36 [Epoch 248] (459ms) Posterior free-energy 8.08704640e+07 = KL from prior 1.55923926e+03 - log-likelihood -8.08689040e+07
# 10/08/2021 15:23:36 [Epoch 249] (484ms) Posterior free-energy 8.08706400e+07 = KL from prior 1.58351709e+03 - log-likelihood -8.08690560e+07
# 10/08/2021 15:23:37 [Epoch 250] (445ms) Posterior free-energy 8.08705840e+07 = KL from prior 1.57219031e+03 - log-likelihood -8.08690080e+07
# 10/08/2021 15:23:37 [Epoch 251] (421ms) Posterior free-energy 8.08697680e+07 = KL from prior 1.52140723e+03 - log-likelihood -8.08682480e+07
# 10/08/2021 15:23:38 [Epoch 252] (420ms) Posterior free-energy 8.08671280e+07 = KL from prior 1.59131421e+03 - log-likelihood -8.08655360e+07
# 10/08/2021 15:23:38 [Epoch 253] (471ms) Posterior free-energy 8.08653120e+07 = KL from prior 1.60684375e+03 - log-likelihood -8.08637040e+07
# 10/08/2021 15:23:39 [Epoch 254] (493ms) Posterior free-energy 8.08677360e+07 = KL from prior 1.56906372e+03 - log-likelihood -8.08661680e+07
# 10/08/2021 15:23:39 [Epoch 255] (467ms) Posterior free-energy 8.08671440e+07 = KL from prior 1.52127429e+03 - log-likelihood -8.08656240e+07
# 10/08/2021 15:23:40 [Epoch 256] (475ms) Posterior free-energy 8.08658240e+07 = KL from prior 1.55231165e+03 - log-likelihood -8.08642720e+07
# 10/08/2021 15:23:40 [Epoch 257] (496ms) Posterior free-energy 8.08628560e+07 = KL from prior 1.56951855e+03 - log-likelihood -8.08612880e+07
# 10/08/2021 15:23:41 [Epoch 258] (499ms) Posterior free-energy 8.08632640e+07 = KL from prior 1.53335266e+03 - log-likelihood -8.08617280e+07
# 10/08/2021 15:23:41 [Epoch 259] (477ms) Posterior free-energy 8.08632640e+07 = KL from prior 1.49702271e+03 - log-likelihood -8.08617680e+07
# 10/08/2021 15:23:42 [Epoch 260] (476ms) Posterior free-energy 8.08638000e+07 = KL from prior 1.57814856e+03 - log-likelihood -8.08622240e+07
# 10/08/2021 15:23:42 [Epoch 261] (692ms) Posterior free-energy 8.08615440e+07 = KL from prior 1.54409167e+03 - log-likelihood -8.08600000e+07
# 10/08/2021 15:23:43 [Epoch 262] (650ms) Posterior free-energy 8.08617120e+07 = KL from prior 1.53708240e+03 - log-likelihood -8.08601760e+07
# 10/08/2021 15:23:44 [Epoch 263] (593ms) Posterior free-energy 8.08619920e+07 = KL from prior 1.54398193e+03 - log-likelihood -8.08604480e+07
# 10/08/2021 15:23:44 [Epoch 264] (506ms) Posterior free-energy 8.08616640e+07 = KL from prior 1.48181421e+03 - log-likelihood -8.08601840e+07
# 10/08/2021 15:23:45 [Epoch 265] (520ms) Posterior free-energy 8.08606640e+07 = KL from prior 1.49618286e+03 - log-likelihood -8.08591680e+07
# 10/08/2021 15:23:45 [Epoch 266] (476ms) Posterior free-energy 8.08607520e+07 = KL from prior 1.51506079e+03 - log-likelihood -8.08592400e+07
# 10/08/2021 15:23:46 [Epoch 267] (445ms) Posterior free-energy 8.08598480e+07 = KL from prior 1.53873669e+03 - log-likelihood -8.08583120e+07
# 10/08/2021 15:23:46 [Epoch 268] (438ms) Posterior free-energy 8.08596800e+07 = KL from prior 1.46249915e+03 - log-likelihood -8.08582160e+07
# 10/08/2021 15:23:46 [Epoch 269] (480ms) Posterior free-energy 8.08585600e+07 = KL from prior 1.51818201e+03 - log-likelihood -8.08570400e+07
# 10/08/2021 15:23:47 [Epoch 270] (475ms) Posterior free-energy 8.08589680e+07 = KL from prior 1.49179663e+03 - log-likelihood -8.08574800e+07
# 10/08/2021 15:23:47 [Epoch 271] (576ms) Posterior free-energy 8.08593360e+07 = KL from prior 1.46734009e+03 - log-likelihood -8.08578720e+07
# 10/08/2021 15:23:48 [Epoch 272] (503ms) Posterior free-energy 8.08553760e+07 = KL from prior 1.51797095e+03 - log-likelihood -8.08538560e+07
# 10/08/2021 15:23:48 [Epoch 273] (483ms) Posterior free-energy 8.08551600e+07 = KL from prior 1.50438196e+03 - log-likelihood -8.08536560e+07
# 10/08/2021 15:23:49 [Epoch 274] (461ms) Posterior free-energy 8.08567200e+07 = KL from prior 1.49052576e+03 - log-likelihood -8.08552320e+07
# 10/08/2021 15:23:49 [Epoch 275] (453ms) Posterior free-energy 8.08536640e+07 = KL from prior 1.51072778e+03 - log-likelihood -8.08521520e+07
# 10/08/2021 15:23:50 [Epoch 276] (501ms) Posterior free-energy 8.08554720e+07 = KL from prior 1.48939771e+03 - log-likelihood -8.08539840e+07
# 10/08/2021 15:23:50 [Epoch 277] (486ms) Posterior free-energy 8.08562880e+07 = KL from prior 1.46085254e+03 - log-likelihood -8.08548240e+07
# 10/08/2021 15:23:51 [Epoch 278] (530ms) Posterior free-energy 8.08561600e+07 = KL from prior 1.50708130e+03 - log-likelihood -8.08546560e+07
# 10/08/2021 15:23:51 [Epoch 279] (508ms) Posterior free-energy 8.08539200e+07 = KL from prior 1.50116235e+03 - log-likelihood -8.08524160e+07
# 10/08/2021 15:23:52 [Epoch 280] (496ms) Posterior free-energy 8.08537840e+07 = KL from prior 1.47497644e+03 - log-likelihood -8.08523120e+07
# 10/08/2021 15:23:52 [Epoch 281] (522ms) Posterior free-energy 8.08565920e+07 = KL from prior 1.46784583e+03 - log-likelihood -8.08551280e+07
# 10/08/2021 15:23:53 [Epoch 282] (480ms) Posterior free-energy 8.08563360e+07 = KL from prior 1.43212036e+03 - log-likelihood -8.08549040e+07
# 10/08/2021 15:23:53 [Epoch 283] (564ms) Posterior free-energy 8.08535200e+07 = KL from prior 1.50509595e+03 - log-likelihood -8.08520160e+07
# 10/08/2021 15:23:54 [Epoch 284] (468ms) Posterior free-energy 8.08525760e+07 = KL from prior 1.50469849e+03 - log-likelihood -8.08510720e+07
# 10/08/2021 15:23:54 [Epoch 285] (424ms) Posterior free-energy 8.08541360e+07 = KL from prior 1.47639661e+03 - log-likelihood -8.08526560e+07
# 10/08/2021 15:23:55 [Epoch 286] (428ms) Posterior free-energy 8.08520560e+07 = KL from prior 1.44784863e+03 - log-likelihood -8.08506080e+07
# 10/08/2021 15:23:55 [Epoch 287] (485ms) Posterior free-energy 8.08516800e+07 = KL from prior 1.47266614e+03 - log-likelihood -8.08502080e+07
# 10/08/2021 15:23:56 [Epoch 288] (519ms) Posterior free-energy 8.08529440e+07 = KL from prior 1.45810828e+03 - log-likelihood -8.08514880e+07
# 10/08/2021 15:23:56 [Epoch 289] (403ms) Posterior free-energy 8.08501440e+07 = KL from prior 1.51951709e+03 - log-likelihood -8.08486240e+07
# 10/08/2021 15:23:57 [Epoch 290] (416ms) Posterior free-energy 8.08518640e+07 = KL from prior 1.48335181e+03 - log-likelihood -8.08503840e+07
# 10/08/2021 15:23:57 [Epoch 291] (469ms) Posterior free-energy 8.08511200e+07 = KL from prior 1.47999524e+03 - log-likelihood -8.08496400e+07
# 10/08/2021 15:23:58 [Epoch 292] (472ms) Posterior free-energy 8.08518000e+07 = KL from prior 1.50435413e+03 - log-likelihood -8.08502960e+07
# 10/08/2021 15:23:58 [Epoch 293] (474ms) Posterior free-energy 8.08517280e+07 = KL from prior 1.43687415e+03 - log-likelihood -8.08502880e+07
# 10/08/2021 15:23:59 [Epoch 294] (474ms) Posterior free-energy 8.08507040e+07 = KL from prior 1.44493933e+03 - log-likelihood -8.08492560e+07
# 10/08/2021 15:23:59 [Epoch 295] (484ms) Posterior free-energy 8.08505440e+07 = KL from prior 1.49680151e+03 - log-likelihood -8.08490480e+07
# 10/08/2021 15:24:00 [Epoch 296] (494ms) Posterior free-energy 8.08502400e+07 = KL from prior 1.45801208e+03 - log-likelihood -8.08487840e+07
# 10/08/2021 15:24:00 [Epoch 297] (441ms) Posterior free-energy 8.08501440e+07 = KL from prior 1.46718469e+03 - log-likelihood -8.08486800e+07
# 10/08/2021 15:24:00 [Epoch 298] (445ms) Posterior free-energy 8.08491600e+07 = KL from prior 1.47524353e+03 - log-likelihood -8.08476880e+07
# 10/08/2021 15:24:01 [Epoch 299] (416ms) Posterior free-energy 8.08495840e+07 = KL from prior 1.50502954e+03 - log-likelihood -8.08480800e+07
# 10/08/2021 15:24:01 [Epoch 300] (480ms) Posterior free-energy 8.08493920e+07 = KL from prior 1.48664624e+03 - log-likelihood -8.08479040e+07
# 10/08/2021 15:24:02 [Epoch 301] (487ms) Posterior free-energy 8.08488080e+07 = KL from prior 1.48255603e+03 - log-likelihood -8.08473280e+07
# 10/08/2021 15:24:02 [Epoch 302] (479ms) Posterior free-energy 8.08475520e+07 = KL from prior 1.49932983e+03 - log-likelihood -8.08460560e+07
# 10/08/2021 15:24:03 [Epoch 303] (477ms) Posterior free-energy 8.08482960e+07 = KL from prior 1.50960120e+03 - log-likelihood -8.08467840e+07
# 10/08/2021 15:24:03 [Epoch 304] (478ms) Posterior free-energy 8.08485120e+07 = KL from prior 1.45902698e+03 - log-likelihood -8.08470560e+07
# 10/08/2021 15:24:04 [Epoch 305] (481ms) Posterior free-energy 8.08494480e+07 = KL from prior 1.49804736e+03 - log-likelihood -8.08479520e+07
# 10/08/2021 15:24:04 [Epoch 306] (571ms) Posterior free-energy 8.08471040e+07 = KL from prior 1.51427466e+03 - log-likelihood -8.08455920e+07
# 10/08/2021 15:24:05 [Epoch 307] (476ms) Posterior free-energy 8.08472720e+07 = KL from prior 1.50761670e+03 - log-likelihood -8.08457680e+07
# 10/08/2021 15:24:05 [Epoch 308] (678ms) Posterior free-energy 8.08485520e+07 = KL from prior 1.45033679e+03 - log-likelihood -8.08471040e+07
# 10/08/2021 15:24:06 [Epoch 309] (612ms) Posterior free-energy 8.08470880e+07 = KL from prior 1.54277612e+03 - log-likelihood -8.08455440e+07
# 10/08/2021 15:24:07 [Epoch 310] (541ms) Posterior free-energy 8.08460880e+07 = KL from prior 1.52512952e+03 - log-likelihood -8.08445600e+07
# 10/08/2021 15:24:07 [Epoch 311] (497ms) Posterior free-energy 8.08471120e+07 = KL from prior 1.49500122e+03 - log-likelihood -8.08456160e+07
# 10/08/2021 15:24:08 [Epoch 312] (477ms) Posterior free-energy 8.08467840e+07 = KL from prior 1.50859863e+03 - log-likelihood -8.08452720e+07
# 10/08/2021 15:24:08 [Epoch 313] (518ms) Posterior free-energy 8.08464720e+07 = KL from prior 1.52652258e+03 - log-likelihood -8.08449440e+07
# 10/08/2021 15:24:09 [Epoch 314] (430ms) Posterior free-energy 8.08463440e+07 = KL from prior 1.48433838e+03 - log-likelihood -8.08448560e+07
# 10/08/2021 15:24:09 [Epoch 315] (448ms) Posterior free-energy 8.08454320e+07 = KL from prior 1.51471899e+03 - log-likelihood -8.08439200e+07
# 10/08/2021 15:24:09 [Epoch 316] (483ms) Posterior free-energy 8.08462800e+07 = KL from prior 1.54019690e+03 - log-likelihood -8.08447360e+07
# 10/08/2021 15:24:10 [Epoch 317] (483ms) Posterior free-energy 8.08456640e+07 = KL from prior 1.51720459e+03 - log-likelihood -8.08441440e+07
# 10/08/2021 15:24:10 [Epoch 318] (473ms) Posterior free-energy 8.08458400e+07 = KL from prior 1.48988354e+03 - log-likelihood -8.08443520e+07
# 10/08/2021 15:24:11 [Epoch 319] (483ms) Posterior free-energy 8.08456640e+07 = KL from prior 1.49885010e+03 - log-likelihood -8.08441680e+07
# 10/08/2021 15:24:11 [Epoch 320] (471ms) Posterior free-energy 8.08460240e+07 = KL from prior 1.49602332e+03 - log-likelihood -8.08445280e+07
# 10/08/2021 15:24:12 [Epoch 321] (460ms) Posterior free-energy 8.08455920e+07 = KL from prior 1.54460962e+03 - log-likelihood -8.08440480e+07
# 10/08/2021 15:24:12 [Epoch 322] (433ms) Posterior free-energy 8.08449680e+07 = KL from prior 1.53073901e+03 - log-likelihood -8.08434400e+07
# 10/08/2021 15:24:13 [Epoch 323] (403ms) Posterior free-energy 8.08450400e+07 = KL from prior 1.48874304e+03 - log-likelihood -8.08435520e+07
# 10/08/2021 15:24:13 [Epoch 324] (422ms) Posterior free-energy 8.08459200e+07 = KL from prior 1.55434521e+03 - log-likelihood -8.08443680e+07
# 10/08/2021 15:24:14 [Epoch 325] (474ms) Posterior free-energy 8.08455200e+07 = KL from prior 1.51327661e+03 - log-likelihood -8.08440080e+07
# 10/08/2021 15:24:14 [Epoch 326] (442ms) Posterior free-energy 8.08435520e+07 = KL from prior 1.53164783e+03 - log-likelihood -8.08420240e+07
# 10/08/2021 15:24:14 [Epoch 327] (434ms) Posterior free-energy 8.08454640e+07 = KL from prior 1.50882776e+03 - log-likelihood -8.08439520e+07
# 10/08/2021 15:24:15 [Epoch 328] (459ms) Posterior free-energy 8.08441680e+07 = KL from prior 1.55498291e+03 - log-likelihood -8.08426160e+07
# 10/08/2021 15:24:15 [Epoch 329] (521ms) Posterior free-energy 8.08445360e+07 = KL from prior 1.54195691e+03 - log-likelihood -8.08429920e+07
# 10/08/2021 15:24:16 [Epoch 330] (494ms) Posterior free-energy 8.08443840e+07 = KL from prior 1.52307227e+03 - log-likelihood -8.08428640e+07
# 10/08/2021 15:24:16 [Epoch 331] (503ms) Posterior free-energy 8.08437760e+07 = KL from prior 1.51058533e+03 - log-likelihood -8.08422640e+07
# 10/08/2021 15:24:17 [Epoch 332] (463ms) Posterior free-energy 8.08436640e+07 = KL from prior 1.56536633e+03 - log-likelihood -8.08420960e+07
# 10/08/2021 15:24:17 [Epoch 333] (478ms) Posterior free-energy 8.08436960e+07 = KL from prior 1.51999219e+03 - log-likelihood -8.08421760e+07
# 10/08/2021 15:24:18 [Epoch 334] (504ms) Posterior free-energy 8.08446480e+07 = KL from prior 1.49402515e+03 - log-likelihood -8.08431520e+07
# 10/08/2021 15:24:18 [Epoch 335] (507ms) Posterior free-energy 8.08439440e+07 = KL from prior 1.55195032e+03 - log-likelihood -8.08423920e+07
# 10/08/2021 15:24:19 [Epoch 336] (507ms) Posterior free-energy 8.08426080e+07 = KL from prior 1.55619165e+03 - log-likelihood -8.08410480e+07
# 10/08/2021 15:24:19 [Epoch 337] (531ms) Posterior free-energy 8.08446240e+07 = KL from prior 1.50878638e+03 - log-likelihood -8.08431120e+07
# 10/08/2021 15:24:20 [Epoch 338] (530ms) Posterior free-energy 8.08436480e+07 = KL from prior 1.54207129e+03 - log-likelihood -8.08421040e+07
# 10/08/2021 15:24:21 [Epoch 339] (530ms) Posterior free-energy 8.08428240e+07 = KL from prior 1.57503760e+03 - log-likelihood -8.08412480e+07
# 10/08/2021 15:24:21 [Epoch 340] (529ms) Posterior free-energy 8.08431280e+07 = KL from prior 1.51432568e+03 - log-likelihood -8.08416160e+07
# 10/08/2021 15:24:22 [Epoch 341] (526ms) Posterior free-energy 8.08421440e+07 = KL from prior 1.54536926e+03 - log-likelihood -8.08406000e+07
# 10/08/2021 15:24:22 [Epoch 342] (607ms) Posterior free-energy 8.08430320e+07 = KL from prior 1.54976770e+03 - log-likelihood -8.08414800e+07
# 10/08/2021 15:24:23 [Epoch 343] (741ms) Posterior free-energy 8.08434400e+07 = KL from prior 1.49116382e+03 - log-likelihood -8.08419520e+07
# 10/08/2021 15:24:23 [Epoch 344] (564ms) Posterior free-energy 8.08417600e+07 = KL from prior 1.55384412e+03 - log-likelihood -8.08402080e+07
# 10/08/2021 15:24:24 [Epoch 345] (513ms) Posterior free-energy 8.08409600e+07 = KL from prior 1.54420935e+03 - log-likelihood -8.08394160e+07
# 10/08/2021 15:24:25 [Epoch 346] (497ms) Posterior free-energy 8.08417680e+07 = KL from prior 1.56745679e+03 - log-likelihood -8.08402000e+07
# 10/08/2021 15:24:25 [Epoch 347] (468ms) Posterior free-energy 8.08421680e+07 = KL from prior 1.57921509e+03 - log-likelihood -8.08405920e+07
# 10/08/2021 15:24:25 [Epoch 348] (449ms) Posterior free-energy 8.08422240e+07 = KL from prior 1.54315454e+03 - log-likelihood -8.08406800e+07
# 10/08/2021 15:24:26 [Epoch 349] (439ms) Posterior free-energy 8.08424880e+07 = KL from prior 1.57799438e+03 - log-likelihood -8.08409120e+07
# 10/08/2021 15:24:26 [Epoch 350] (490ms) Posterior free-energy 8.08409040e+07 = KL from prior 1.56386230e+03 - log-likelihood -8.08393440e+07
# 10/08/2021 15:24:27 [Epoch 351] (491ms) Posterior free-energy 8.08416240e+07 = KL from prior 1.59459448e+03 - log-likelihood -8.08400320e+07
# 10/08/2021 15:24:27 [Epoch 352] (492ms) Posterior free-energy 8.08395840e+07 = KL from prior 1.61085840e+03 - log-likelihood -8.08379760e+07
# 10/08/2021 15:24:28 [Epoch 353] (489ms) Posterior free-energy 8.08408080e+07 = KL from prior 1.60075623e+03 - log-likelihood -8.08392080e+07
# 10/08/2021 15:24:28 [Epoch 354] (485ms) Posterior free-energy 8.08408000e+07 = KL from prior 1.59423706e+03 - log-likelihood -8.08392080e+07
# 10/08/2021 15:24:29 [Epoch 355] (487ms) Posterior free-energy 8.08413040e+07 = KL from prior 1.54205933e+03 - log-likelihood -8.08397600e+07
# 10/08/2021 15:24:29 [Epoch 356] (489ms) Posterior free-energy 8.08407520e+07 = KL from prior 1.54803687e+03 - log-likelihood -8.08392000e+07
# 10/08/2021 15:24:30 [Epoch 357] (494ms) Posterior free-energy 8.08415760e+07 = KL from prior 1.53176160e+03 - log-likelihood -8.08400480e+07
# 10/08/2021 15:24:30 [Epoch 358] (655ms) Posterior free-energy 8.08399280e+07 = KL from prior 1.59905261e+03 - log-likelihood -8.08383280e+07
# 10/08/2021 15:24:31 [Epoch 359] (606ms) Posterior free-energy 8.08408880e+07 = KL from prior 1.58389185e+03 - log-likelihood -8.08393040e+07
# 10/08/2021 15:24:32 [Epoch 360] (545ms) Posterior free-energy 8.08403280e+07 = KL from prior 1.56514880e+03 - log-likelihood -8.08387600e+07
# 10/08/2021 15:24:32 [Epoch 361] (499ms) Posterior free-energy 8.08400240e+07 = KL from prior 1.57362781e+03 - log-likelihood -8.08384480e+07
# 10/08/2021 15:24:33 [Epoch 362] (480ms) Posterior free-energy 8.08404720e+07 = KL from prior 1.55864355e+03 - log-likelihood -8.08389120e+07
# 10/08/2021 15:24:33 [Epoch 363] (518ms) Posterior free-energy 8.08398880e+07 = KL from prior 1.59262476e+03 - log-likelihood -8.08382960e+07
# 10/08/2021 15:24:34 [Epoch 364] (528ms) Posterior free-energy 8.08398720e+07 = KL from prior 1.62993091e+03 - log-likelihood -8.08382400e+07
# 10/08/2021 15:24:34 [Epoch 365] (499ms) Posterior free-energy 8.08398000e+07 = KL from prior 1.57737915e+03 - log-likelihood -8.08382240e+07
# 10/08/2021 15:24:35 [Epoch 366] (491ms) Posterior free-energy 8.08395760e+07 = KL from prior 1.61282690e+03 - log-likelihood -8.08379600e+07
# 10/08/2021 15:24:35 [Epoch 367] (478ms) Posterior free-energy 8.08393040e+07 = KL from prior 1.58031067e+03 - log-likelihood -8.08377200e+07
# 10/08/2021 15:24:36 [Epoch 368] (421ms) Posterior free-energy 8.08391840e+07 = KL from prior 1.60597949e+03 - log-likelihood -8.08375760e+07
# 10/08/2021 15:24:36 [Epoch 369] (492ms) Posterior free-energy 8.08393120e+07 = KL from prior 1.58329333e+03 - log-likelihood -8.08377280e+07
# 10/08/2021 15:24:37 [Epoch 370] (480ms) Posterior free-energy 8.08396960e+07 = KL from prior 1.59327075e+03 - log-likelihood -8.08381040e+07
# 10/08/2021 15:24:37 [Epoch 371] (494ms) Posterior free-energy 8.08400880e+07 = KL from prior 1.55808179e+03 - log-likelihood -8.08385280e+07
# 10/08/2021 15:24:37 [Epoch 372] (496ms) Posterior free-energy 8.08394640e+07 = KL from prior 1.56830127e+03 - log-likelihood -8.08378960e+07
# 10/08/2021 15:24:38 [Epoch 373] (495ms) Posterior free-energy 8.08387120e+07 = KL from prior 1.60074121e+03 - log-likelihood -8.08371120e+07
# 10/08/2021 15:24:38 [Epoch 374] (491ms) Posterior free-energy 8.08394320e+07 = KL from prior 1.57042395e+03 - log-likelihood -8.08378640e+07
# 10/08/2021 15:24:39 [Epoch 375] (489ms) Posterior free-energy 8.08392880e+07 = KL from prior 1.55756934e+03 - log-likelihood -8.08377280e+07
# 10/08/2021 15:24:39 [Epoch 376] (509ms) Posterior free-energy 8.08386480e+07 = KL from prior 1.61166846e+03 - log-likelihood -8.08370400e+07
# 10/08/2021 15:24:40 [Epoch 377] (477ms) Posterior free-energy 8.08398320e+07 = KL from prior 1.56376025e+03 - log-likelihood -8.08382720e+07
# Epoch   377: reducing learning rate of group 0 to 5.0000e-02.
# Epoch   377: reducing learning rate of group 1 to 5.0000e-04.
# Epoch   377: reducing learning rate of group 2 to 5.0000e-02.
# Epoch   377: reducing learning rate of group 3 to 5.0000e-04.
# 10/08/2021 15:24:40 [Epoch 378] (435ms) Posterior free-energy 8.08379360e+07 = KL from prior 1.59929468e+03 - log-likelihood -8.08363360e+07
# 10/08/2021 15:24:41 [Epoch 379] (418ms) Posterior free-energy 8.08391600e+07 = KL from prior 1.60886011e+03 - log-likelihood -8.08375520e+07
# 10/08/2021 15:24:41 [Epoch 380] (487ms) Posterior free-energy 8.08380960e+07 = KL from prior 1.57409595e+03 - log-likelihood -8.08365200e+07
# 10/08/2021 15:24:42 [Epoch 381] (484ms) Posterior free-energy 8.08383840e+07 = KL from prior 1.57184277e+03 - log-likelihood -8.08368160e+07
# 10/08/2021 15:24:42 [Epoch 382] (482ms) Posterior free-energy 8.08381600e+07 = KL from prior 1.58486450e+03 - log-likelihood -8.08365760e+07
# 10/08/2021 15:24:43 [Epoch 383] (490ms) Posterior free-energy 8.08390320e+07 = KL from prior 1.58865222e+03 - log-likelihood -8.08374400e+07
# 10/08/2021 15:24:43 [Epoch 384] (492ms) Posterior free-energy 8.08387680e+07 = KL from prior 1.56620105e+03 - log-likelihood -8.08372000e+07
# 10/08/2021 15:24:44 [Epoch 385] (504ms) Posterior free-energy 8.08377680e+07 = KL from prior 1.60060388e+03 - log-likelihood -8.08361680e+07
# 10/08/2021 15:24:44 [Epoch 386] (490ms) Posterior free-energy 8.08388080e+07 = KL from prior 1.56551355e+03 - log-likelihood -8.08372400e+07
# 10/08/2021 15:24:45 [Epoch 387] (508ms) Posterior free-energy 8.08384640e+07 = KL from prior 1.60664685e+03 - log-likelihood -8.08368560e+07
# 10/08/2021 15:24:45 [Epoch 388] (641ms) Posterior free-energy 8.08373600e+07 = KL from prior 1.62205432e+03 - log-likelihood -8.08357360e+07
# 10/08/2021 15:24:46 [Epoch 389] (612ms) Posterior free-energy 8.08383520e+07 = KL from prior 1.56264624e+03 - log-likelihood -8.08367920e+07
# 10/08/2021 15:24:47 [Epoch 390] (581ms) Posterior free-energy 8.08386880e+07 = KL from prior 1.57745667e+03 - log-likelihood -8.08371120e+07
# 10/08/2021 15:24:47 [Epoch 391] (532ms) Posterior free-energy 8.08374800e+07 = KL from prior 1.60246655e+03 - log-likelihood -8.08358800e+07
# 10/08/2021 15:24:48 [Epoch 392] (501ms) Posterior free-energy 8.08376800e+07 = KL from prior 1.56900366e+03 - log-likelihood -8.08361120e+07
# 10/08/2021 15:24:48 [Epoch 393] (441ms) Posterior free-energy 8.08386800e+07 = KL from prior 1.57000330e+03 - log-likelihood -8.08371120e+07
# 10/08/2021 15:24:49 [Epoch 394] (428ms) Posterior free-energy 8.08376640e+07 = KL from prior 1.60518762e+03 - log-likelihood -8.08360560e+07
# 10/08/2021 15:24:49 [Epoch 395] (416ms) Posterior free-energy 8.08371840e+07 = KL from prior 1.63238501e+03 - log-likelihood -8.08355520e+07
# 10/08/2021 15:24:49 [Epoch 396] (468ms) Posterior free-energy 8.08372560e+07 = KL from prior 1.62142126e+03 - log-likelihood -8.08356320e+07
# 10/08/2021 15:24:50 [Epoch 397] (466ms) Posterior free-energy 8.08370400e+07 = KL from prior 1.60471082e+03 - log-likelihood -8.08354320e+07
# 10/08/2021 15:24:50 [Epoch 398] (509ms) Posterior free-energy 8.08374320e+07 = KL from prior 1.56997205e+03 - log-likelihood -8.08358640e+07
# 10/08/2021 15:24:51 [Epoch 399] (525ms) Posterior free-energy 8.08373840e+07 = KL from prior 1.56507886e+03 - log-likelihood -8.08358160e+07
# 10/08/2021 15:24:51 [Epoch 400] (490ms) Posterior free-energy 8.08365600e+07 = KL from prior 1.64091187e+03 - log-likelihood -8.08349200e+07
# 10/08/2021 15:24:51 Saving checkpoint...

# %%
if TRAIN:
    utils.plot_losses(losses)

# %%
def task_labeler(task):
    return task


def rest_task_labeler(task):
    if task == 'rest':
        return 'Rest'
    else:
        return 'Task'

# %%
def subject_labeler(subject):
    return str(subject)

# %%
def stimulus_labeler(stimulus):
    stim = stimulus[-1]
    if int(stim) == 1 or int(stim) == 2:
        return 'State 0'
    elif int(stim) == 3 or int(stim) == 4:
        return 'State 1'
    elif int(stim) == 5 or int(stim) == 6:
        return 'State 2'
    elif int(stim) == 7 or int(stim) == 8:
        return 'State 3'
    else:
        print ('Error')

# %%
hyperparams = dtfa.variational.hyperparams.state_vardict()
tasks = dtfa.tasks()
subjects = dtfa.subjects()
interactions = OrderedSet(list(itertools.product(subjects, tasks)))

# %%
interactions
# Out:
# OrderedSet([(1, 'video1'), (1, 'video2'), (1, 'video3'), (1, 'video4'), (1, 'video5'), (1, 'video6'), (1, 'video7'), (1, 'video8'), (2, 'video1'), (2, 'video2'), (2, 'video3'), (2, 'video4'), (2, 'video5'), (2, 'video6'), (2, 'video7'), (2, 'video8')])

# %%
dtfa.scatter_subject_embedding(labeler=subject_labeler, figsize=None, colormap='Set1',
                            filename='subject_norest_subject_embedding' + scenario_name + '.png')
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch/htfa_torch/utils.py:149: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.scatter_subject_weight_embedding(labeler=subject_labeler, figsize=None, colormap='Set1',
                            filename='subject_norest_subject_weight_embedding' + scenario_name + '.png')
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch/htfa_torch/utils.py:149: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.scatter_task_embedding(labeler=stimulus_labeler,figsize=None, colormap='Set1',
                            filename='subject_norest_task_embedding' + scenario_name + '.png')
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch/htfa_torch/utils.py:149: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def scatter_interactions_embedding(self, labeler=None, filename='', show=True,
                                   xlims=None, ylims=None, figsize=utils.FIGSIZE,
                                   colormap='Accent', serialize_data=True,
                                   plot_ellipse=True, legend_ordering=None,nstd=3):

    def eigsorted(cov):
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        return vals[order], vecs[:, order]
    
    if filename == '':
        filename = self.common_name() + '_task_embedding.pdf'
    hyperparams = self.variational.hyperparams.state_vardict()
    tasks = self.tasks()
    subjects = self.subjects()
    z_p_mu = hyperparams['subject_weight']['mu'].data
    z_s_mu = hyperparams['task']['mu'].data
    interactions = OrderedSet(list(itertools.product(subjects, tasks)))
    z_ps_mu = np.zeros(shape=(len(interactions),2))
    count = 0
    for p in range (len(subjects)):
        for t in range(len(tasks)):
            joint_embed = torch.cat((z_p_mu[p], z_s_mu[t]), dim=-1)
            interaction_embed = self.decoder.interaction_embedding(
                joint_embed).data
            z_ps_mu[count,:] = self.decoder.interaction_embedding_out(torch.cat((interaction_embed,
                                                                                 joint_embed),dim=-1)).data.numpy()
            count += 1
    embedding_name = 'z^{PS}'

    fig, ax = plt.subplots(facecolor='white', figsize=figsize, frameon=True)
    if xlims is not None:
        ax.set_xlim(xlims)
    if ylims is not None:
        ax.set_ylim(ylims)
    ax.set_xticks([])
    ax.set_yticks([])
    task_colors = ['black','darkgreen','red','blue']
    task_low_embeddings = []
    task_high_embeddings = []

    for i in range(len(z_ps_mu)):
        if stimulus_labeler(interactions[i][1]) == 'State 0':
            edgecolor = task_colors[0]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[0], marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[0], marker='^', s=400, linewidth=4)
            task_low_embeddings.append(z_ps_mu[i,:])
        elif stimulus_labeler(interactions[i][1]) == 'State 1':
            edgecolor = task_colors[1]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[1],marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[1],marker='^', s=400, linewidth=4)
            task_high_embeddings.append(z_ps_mu[i,:]) 
        elif stimulus_labeler(interactions[i][1]) == 'State 2':
            edgecolor = task_colors[2]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[2],marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[2],marker='^', s=400, linewidth=4)
            task_high_embeddings.append(z_ps_mu[i,:]) 
        elif stimulus_labeler(interactions[i][1]) == 'State 3':
            edgecolor = task_colors[3]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[3],marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[3],marker='^', s=400, linewidth=4)
            task_high_embeddings.append(z_ps_mu[i,:]) 

    ordered_tasks = ['Baseline','Trial A', 'Trial B', 'Trial C']
    single_task_colors = ['darkgreen','red','blue']
    manual_legend = [mpatches.Patch(color=c,label=t) for (c,t) in zip(task_colors,ordered_tasks)]
    temp_dict = {key:[] for key in subjects}
    linestyle = ['solid','dashed']

    
    plt.legend(handles=manual_legend, prop={'size': 16})
    if filename is not None:
        fig.savefig(filename)
    if show:
        fig.show()
        
    return task_low_embeddings,task_high_embeddings

# %%
def interactions_labeler(subject,task):
    
    return task_labeler(task) + subject_labeler(subject)

# %%
scatter_interactions_embedding(dtfa,labeler=interactions_labeler,
                               filename='subject_norest_interaction_embedding' + scenario_name + '.png',
                               plot_ellipse=True,colormap='tab20',figsize=(5,5),nstd=2)
# Out:
# /home/zulqarnain/anaconda3/envs/htfatorch/lib/python3.7/site-packages/ipykernel_launcher.py:93: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# ([array([-0.18160152,  0.90508544]),
#   array([-0.20922029,  0.97409487]),
#   array([-0.14001185,  0.94781756]),
#   array([-0.16722369,  1.01508975])],
#  [array([ 2.02442932, -1.38760448]),
#   array([ 1.91402209, -1.29659104]),
#   array([ 1.95740259, -1.40294123]),
#   array([ 2.01545572, -1.40069997]),
#   array([ 2.13433981, -1.57531989]),
#   array([ 2.0692625 , -1.45561981]),
#   array([ 2.0639112 , -1.35237074]),
#   array([ 1.95358062, -1.26148105]),
#   array([ 1.99688458, -1.36770749]),
#   array([ 2.0549376 , -1.36546612]),
#   array([ 2.17382169, -1.54008603]),
#   array([ 2.10874438, -1.42038608])])
