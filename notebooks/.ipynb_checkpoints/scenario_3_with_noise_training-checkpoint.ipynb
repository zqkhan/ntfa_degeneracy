# %%
# %cd ../
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch

# %%
import logging
import numpy as np
import htfa_torch.dtfa as DTFA
import htfa_torch.niidb as niidb
import htfa_torch.utils as utils
import matplotlib.pyplot as plt
# Out:
# /home/zulqarnain/anaconda3/envs/htfatorch/lib/python3.7/site-packages/nilearn/datasets/__init__.py:89: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
import itertools
from torch.nn.functional import softplus
import matplotlib.patches as mpatches
from ordered_set import OrderedSet

# %%
import torch

# %%
# %matplotlib inline

# %%
TRAIN = True

# %%
logging.basicConfig(format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %H:%M:%S',
                    level=logging.INFO)

# %%
scenario = '3'
noise_factor = 10
num_subjects = 2
db_file = 'data/simulated_simplified_data_' + scenario + '_' + str(num_subjects)+ '_' + str(noise_factor) + '.db'
scenario_name = 'scenario_' + scenario + '_' + str(num_subjects)+ '_' + str(noise_factor)
TRAIN = True
synthetic_db = niidb.FMriActivationsDb(db_file)

# %%
dtfa = DTFA.DeepTFA(synthetic_db.all(), mask='/home/zulqarnain/fmri_data/simulated_degeneracy_data/wholebrain.nii.gz', num_factors=9, embedding_dim=2)
# Out:
# 10/08/2021 15:22:02 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video1_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:02 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video2_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:02 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video3_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:02 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video4_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:02 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video5_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:03 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video6_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:03 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video7_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:03 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_1_video8_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:03 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video1_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:03 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video2_low_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:04 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video3_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:04 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video4_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:04 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video5_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:04 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video6_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:04 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video7_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)
# 10/08/2021 15:22:04 Loading Nifti image /home/zulqarnain/fmri_data/simulated_simplified_data_C/scenario_3_subjects_2_10/nifti_files/participant_2_video8_high_0.nii with mask /home/zulqarnain/fmri_data/simulated_simplified_data_C/wholebrain.nii.gz (zscore=False, smooth=None, zscore_by_rest=False)

# %%
dtfa.num_blocks
# Out:
# 16

# %%
dtfa.tasks()
# Out:
# OrderedSet(['video1', 'video2', 'video3', 'video4', 'video5', 'video6', 'video7', 'video8'])

# %%
dtfa.subjects()
# Out:
# OrderedSet([1, 2])

# %%
dtfa.visualize_factor_embedding()
# Out:
# (<nilearn.plotting.displays.OrthoProjector at 0x7fd4eb061c50>,
#  tensor([[-30.8302,  -6.5316,  48.9017],
#          [ 34.0457, -67.5875, -18.9482],
#          [ 33.5743,  13.8463,  42.6060],
#          [-30.1584, -70.4496,  22.4380],
#          [ 38.6773,  -0.2138, -18.8635],
#          [ -4.9230,  51.8148,   6.7999],
#          [-23.6542, -60.1079, -38.3712],
#          [ 30.6495, -49.9128,  45.1975],
#          [-40.7281,  -2.1589, -14.2572]]),
#  tensor([6.5668, 6.4757, 6.3957, 6.5191, 6.4349, 6.4577, 6.3440, 6.5110, 6.4580]))

# %%
if TRAIN:
    losses = dtfa.train(num_steps=500, learning_rate={'q': 1e-1, 'p': 1e-3}, log_level=logging.INFO, num_particles=1,
                        batch_size=60, use_cuda=True, checkpoint_steps=500, blocks_batch_size=60, patience=50)
# Out:
# 10/08/2021 15:22:09 [Epoch 1] (829ms) Posterior free-energy 9.16228160e+07 = KL from prior 8.12896826e+03 - log-likelihood -9.16146880e+07
# 10/08/2021 15:22:09 Saving checkpoint...
# 10/08/2021 15:22:10 [Epoch 2] (388ms) Posterior free-energy 8.91148160e+07 = KL from prior 8.07944189e+03 - log-likelihood -8.91067360e+07
# 10/08/2021 15:22:10 [Epoch 3] (345ms) Posterior free-energy 8.72111760e+07 = KL from prior 8.06753809e+03 - log-likelihood -8.72031120e+07
# 10/08/2021 15:22:11 [Epoch 4] (388ms) Posterior free-energy 8.62580640e+07 = KL from prior 8.09687012e+03 - log-likelihood -8.62499680e+07
# 10/08/2021 15:22:11 [Epoch 5] (370ms) Posterior free-energy 8.52881280e+07 = KL from prior 8.13111182e+03 - log-likelihood -8.52800000e+07
# 10/08/2021 15:22:11 [Epoch 6] (425ms) Posterior free-energy 8.44658320e+07 = KL from prior 8.27666797e+03 - log-likelihood -8.44575520e+07
# 10/08/2021 15:22:12 [Epoch 7] (430ms) Posterior free-energy 8.39021680e+07 = KL from prior 8.34487402e+03 - log-likelihood -8.38938240e+07
# 10/08/2021 15:22:12 [Epoch 8] (386ms) Posterior free-energy 8.35404000e+07 = KL from prior 8.47815039e+03 - log-likelihood -8.35319200e+07
# 10/08/2021 15:22:13 [Epoch 9] (385ms) Posterior free-energy 8.32719600e+07 = KL from prior 8.56417285e+03 - log-likelihood -8.32633920e+07
# 10/08/2021 15:22:13 [Epoch 10] (377ms) Posterior free-energy 8.30383920e+07 = KL from prior 8.67952148e+03 - log-likelihood -8.30297120e+07
# 10/08/2021 15:22:13 [Epoch 11] (398ms) Posterior free-energy 8.28566560e+07 = KL from prior 8.71892090e+03 - log-likelihood -8.28479360e+07
# 10/08/2021 15:22:14 [Epoch 12] (391ms) Posterior free-energy 8.26577440e+07 = KL from prior 8.90530176e+03 - log-likelihood -8.26488400e+07
# 10/08/2021 15:22:14 [Epoch 13] (452ms) Posterior free-energy 8.25858880e+07 = KL from prior 8.93265332e+03 - log-likelihood -8.25769520e+07
# 10/08/2021 15:22:15 [Epoch 14] (436ms) Posterior free-energy 8.24858880e+07 = KL from prior 9.17189062e+03 - log-likelihood -8.24767200e+07
# 10/08/2021 15:22:15 [Epoch 15] (423ms) Posterior free-energy 8.23986480e+07 = KL from prior 9.19586328e+03 - log-likelihood -8.23894560e+07
# 10/08/2021 15:22:15 [Epoch 16] (414ms) Posterior free-energy 8.23692560e+07 = KL from prior 9.22678125e+03 - log-likelihood -8.23600320e+07
# 10/08/2021 15:22:16 [Epoch 17] (467ms) Posterior free-energy 8.22922800e+07 = KL from prior 9.37039746e+03 - log-likelihood -8.22829120e+07
# 10/08/2021 15:22:16 [Epoch 18] (483ms) Posterior free-energy 8.22604240e+07 = KL from prior 9.37705859e+03 - log-likelihood -8.22510480e+07
# 10/08/2021 15:22:17 [Epoch 19] (504ms) Posterior free-energy 8.22096480e+07 = KL from prior 9.48856738e+03 - log-likelihood -8.22001600e+07
# 10/08/2021 15:22:17 [Epoch 20] (503ms) Posterior free-energy 8.21879040e+07 = KL from prior 9.64622070e+03 - log-likelihood -8.21782560e+07
# 10/08/2021 15:22:18 [Epoch 21] (515ms) Posterior free-energy 8.21284880e+07 = KL from prior 9.61600293e+03 - log-likelihood -8.21188720e+07
# 10/08/2021 15:22:18 [Epoch 22] (509ms) Posterior free-energy 8.21020560e+07 = KL from prior 9.76479395e+03 - log-likelihood -8.20922880e+07
# 10/08/2021 15:22:19 [Epoch 23] (507ms) Posterior free-energy 8.20814480e+07 = KL from prior 9.77829980e+03 - log-likelihood -8.20716720e+07
# 10/08/2021 15:22:19 [Epoch 24] (491ms) Posterior free-energy 8.20640080e+07 = KL from prior 9.88001367e+03 - log-likelihood -8.20541280e+07
# 10/08/2021 15:22:20 [Epoch 25] (835ms) Posterior free-energy 8.20343920e+07 = KL from prior 9.96171582e+03 - log-likelihood -8.20244320e+07
# 10/08/2021 15:22:21 [Epoch 26] (963ms) Posterior free-energy 8.20287360e+07 = KL from prior 9.92351562e+03 - log-likelihood -8.20188160e+07
# 10/08/2021 15:22:22 [Epoch 27] (785ms) Posterior free-energy 8.20162560e+07 = KL from prior 1.00518564e+04 - log-likelihood -8.20062080e+07
# 10/08/2021 15:22:23 [Epoch 28] (675ms) Posterior free-energy 8.19939760e+07 = KL from prior 1.00559717e+04 - log-likelihood -8.19839200e+07
# 10/08/2021 15:22:23 [Epoch 29] (527ms) Posterior free-energy 8.19709440e+07 = KL from prior 1.01107334e+04 - log-likelihood -8.19608320e+07
# 10/08/2021 15:22:24 [Epoch 30] (598ms) Posterior free-energy 8.19772480e+07 = KL from prior 1.01965781e+04 - log-likelihood -8.19670480e+07
# 10/08/2021 15:22:24 [Epoch 31] (517ms) Posterior free-energy 8.19497360e+07 = KL from prior 1.02545420e+04 - log-likelihood -8.19394800e+07
# 10/08/2021 15:22:25 [Epoch 32] (472ms) Posterior free-energy 8.19367680e+07 = KL from prior 1.02746104e+04 - log-likelihood -8.19264960e+07
# 10/08/2021 15:22:25 [Epoch 33] (479ms) Posterior free-energy 8.19257520e+07 = KL from prior 1.02786973e+04 - log-likelihood -8.19154720e+07
# 10/08/2021 15:22:26 [Epoch 34] (460ms) Posterior free-energy 8.19119840e+07 = KL from prior 1.03247002e+04 - log-likelihood -8.19016560e+07
# 10/08/2021 15:22:26 [Epoch 35] (476ms) Posterior free-energy 8.18980400e+07 = KL from prior 1.03593223e+04 - log-likelihood -8.18876800e+07
# 10/08/2021 15:22:27 [Epoch 36] (457ms) Posterior free-energy 8.18870800e+07 = KL from prior 1.03818105e+04 - log-likelihood -8.18766960e+07
# 10/08/2021 15:22:27 [Epoch 37] (423ms) Posterior free-energy 8.18952160e+07 = KL from prior 1.03865537e+04 - log-likelihood -8.18848320e+07
# 10/08/2021 15:22:28 [Epoch 38] (422ms) Posterior free-energy 8.18555280e+07 = KL from prior 1.04694131e+04 - log-likelihood -8.18450560e+07
# 10/08/2021 15:22:28 [Epoch 39] (546ms) Posterior free-energy 8.18548960e+07 = KL from prior 1.04068760e+04 - log-likelihood -8.18444880e+07
# 10/08/2021 15:22:29 [Epoch 40] (491ms) Posterior free-energy 8.18487280e+07 = KL from prior 1.05038379e+04 - log-likelihood -8.18382240e+07
# 10/08/2021 15:22:29 [Epoch 41] (437ms) Posterior free-energy 8.18203840e+07 = KL from prior 1.05563721e+04 - log-likelihood -8.18098240e+07
# 10/08/2021 15:22:29 [Epoch 42] (403ms) Posterior free-energy 8.18388720e+07 = KL from prior 1.04397480e+04 - log-likelihood -8.18284320e+07
# 10/08/2021 15:22:30 [Epoch 43] (443ms) Posterior free-energy 8.18197840e+07 = KL from prior 1.06002051e+04 - log-likelihood -8.18091840e+07
# 10/08/2021 15:22:30 [Epoch 44] (463ms) Posterior free-energy 8.18107440e+07 = KL from prior 1.05062939e+04 - log-likelihood -8.18002400e+07
# 10/08/2021 15:22:31 [Epoch 45] (519ms) Posterior free-energy 8.17905120e+07 = KL from prior 1.05681074e+04 - log-likelihood -8.17799440e+07
# 10/08/2021 15:22:31 [Epoch 46] (445ms) Posterior free-energy 8.18035200e+07 = KL from prior 1.05950703e+04 - log-likelihood -8.17929280e+07
# 10/08/2021 15:22:32 [Epoch 47] (446ms) Posterior free-energy 8.17774720e+07 = KL from prior 1.05704746e+04 - log-likelihood -8.17669040e+07
# 10/08/2021 15:22:32 [Epoch 48] (461ms) Posterior free-energy 8.17702640e+07 = KL from prior 1.05920225e+04 - log-likelihood -8.17596720e+07
# 10/08/2021 15:22:33 [Epoch 49] (458ms) Posterior free-energy 8.17644160e+07 = KL from prior 1.05937256e+04 - log-likelihood -8.17538240e+07
# 10/08/2021 15:22:33 [Epoch 50] (420ms) Posterior free-energy 8.17495920e+07 = KL from prior 1.05939189e+04 - log-likelihood -8.17390000e+07
# 10/08/2021 15:22:34 [Epoch 51] (441ms) Posterior free-energy 8.17145760e+07 = KL from prior 1.06622861e+04 - log-likelihood -8.17039120e+07
# 10/08/2021 15:22:34 [Epoch 52] (460ms) Posterior free-energy 8.17258960e+07 = KL from prior 1.07046406e+04 - log-likelihood -8.17151920e+07
# 10/08/2021 15:22:35 [Epoch 53] (484ms) Posterior free-energy 8.16926160e+07 = KL from prior 1.06283984e+04 - log-likelihood -8.16819840e+07
# 10/08/2021 15:22:35 [Epoch 54] (444ms) Posterior free-energy 8.17284080e+07 = KL from prior 1.05765254e+04 - log-likelihood -8.17178320e+07
# 10/08/2021 15:22:35 [Epoch 55] (415ms) Posterior free-energy 8.16862160e+07 = KL from prior 1.06507695e+04 - log-likelihood -8.16755680e+07
# 10/08/2021 15:22:36 [Epoch 56] (497ms) Posterior free-energy 8.16860160e+07 = KL from prior 1.06221641e+04 - log-likelihood -8.16753920e+07
# 10/08/2021 15:22:36 [Epoch 57] (485ms) Posterior free-energy 8.16704080e+07 = KL from prior 1.07142803e+04 - log-likelihood -8.16596960e+07
# 10/08/2021 15:22:37 [Epoch 58] (451ms) Posterior free-energy 8.16530320e+07 = KL from prior 1.06840879e+04 - log-likelihood -8.16423440e+07
# 10/08/2021 15:22:37 [Epoch 59] (405ms) Posterior free-energy 8.16691360e+07 = KL from prior 1.07795625e+04 - log-likelihood -8.16583600e+07
# 10/08/2021 15:22:38 [Epoch 60] (451ms) Posterior free-energy 8.16347440e+07 = KL from prior 1.06794971e+04 - log-likelihood -8.16240640e+07
# 10/08/2021 15:22:38 [Epoch 61] (480ms) Posterior free-energy 8.16292400e+07 = KL from prior 1.06864600e+04 - log-likelihood -8.16185520e+07
# 10/08/2021 15:22:39 [Epoch 62] (491ms) Posterior free-energy 8.16088960e+07 = KL from prior 1.07002305e+04 - log-likelihood -8.15981920e+07
# 10/08/2021 15:22:39 [Epoch 63] (454ms) Posterior free-energy 8.16118960e+07 = KL from prior 1.07427168e+04 - log-likelihood -8.16011520e+07
# 10/08/2021 15:22:40 [Epoch 64] (428ms) Posterior free-energy 8.16093520e+07 = KL from prior 1.07464902e+04 - log-likelihood -8.15986080e+07
# 10/08/2021 15:22:40 [Epoch 65] (458ms) Posterior free-energy 8.16070560e+07 = KL from prior 1.06676738e+04 - log-likelihood -8.15963920e+07
# 10/08/2021 15:22:41 [Epoch 66] (504ms) Posterior free-energy 8.15505440e+07 = KL from prior 1.07620449e+04 - log-likelihood -8.15397840e+07
# 10/08/2021 15:22:41 [Epoch 67] (439ms) Posterior free-energy 8.15619440e+07 = KL from prior 1.06790557e+04 - log-likelihood -8.15512640e+07
# 10/08/2021 15:22:41 [Epoch 68] (419ms) Posterior free-energy 8.15498400e+07 = KL from prior 1.07262129e+04 - log-likelihood -8.15391120e+07
# 10/08/2021 15:22:42 [Epoch 69] (437ms) Posterior free-energy 8.15443040e+07 = KL from prior 1.07142061e+04 - log-likelihood -8.15335920e+07
# 10/08/2021 15:22:42 [Epoch 70] (477ms) Posterior free-energy 8.15432480e+07 = KL from prior 1.06529551e+04 - log-likelihood -8.15325920e+07
# 10/08/2021 15:22:43 [Epoch 71] (456ms) Posterior free-energy 8.15097840e+07 = KL from prior 1.07253584e+04 - log-likelihood -8.14990560e+07
# 10/08/2021 15:22:43 [Epoch 72] (475ms) Posterior free-energy 8.15019360e+07 = KL from prior 1.06133623e+04 - log-likelihood -8.14913200e+07
# 10/08/2021 15:22:44 [Epoch 73] (477ms) Posterior free-energy 8.14979200e+07 = KL from prior 1.06606641e+04 - log-likelihood -8.14872560e+07
# 10/08/2021 15:22:44 [Epoch 74] (506ms) Posterior free-energy 8.14727280e+07 = KL from prior 1.07270605e+04 - log-likelihood -8.14620000e+07
# 10/08/2021 15:22:45 [Epoch 75] (492ms) Posterior free-energy 8.14683120e+07 = KL from prior 1.07448574e+04 - log-likelihood -8.14575680e+07
# 10/08/2021 15:22:45 [Epoch 76] (482ms) Posterior free-energy 8.14669520e+07 = KL from prior 1.07351162e+04 - log-likelihood -8.14562160e+07
# 10/08/2021 15:22:46 [Epoch 77] (471ms) Posterior free-energy 8.14546800e+07 = KL from prior 1.08388848e+04 - log-likelihood -8.14438400e+07
# 10/08/2021 15:22:46 [Epoch 78] (455ms) Posterior free-energy 8.14174560e+07 = KL from prior 1.07139189e+04 - log-likelihood -8.14067440e+07
# 10/08/2021 15:22:47 [Epoch 79] (394ms) Posterior free-energy 8.14350960e+07 = KL from prior 1.07026104e+04 - log-likelihood -8.14243920e+07
# 10/08/2021 15:22:47 [Epoch 80] (467ms) Posterior free-energy 8.13986560e+07 = KL from prior 1.06585029e+04 - log-likelihood -8.13880000e+07
# 10/08/2021 15:22:47 [Epoch 81] (489ms) Posterior free-energy 8.13843520e+07 = KL from prior 1.06791660e+04 - log-likelihood -8.13736720e+07
# 10/08/2021 15:22:48 [Epoch 82] (453ms) Posterior free-energy 8.13806720e+07 = KL from prior 1.07449932e+04 - log-likelihood -8.13699280e+07
# 10/08/2021 15:22:48 [Epoch 83] (428ms) Posterior free-energy 8.13735280e+07 = KL from prior 1.06287451e+04 - log-likelihood -8.13628960e+07
# 10/08/2021 15:22:49 [Epoch 84] (438ms) Posterior free-energy 8.13891040e+07 = KL from prior 1.06558467e+04 - log-likelihood -8.13784480e+07
# 10/08/2021 15:22:49 [Epoch 85] (466ms) Posterior free-energy 8.13454400e+07 = KL from prior 1.06791152e+04 - log-likelihood -8.13347600e+07
# 10/08/2021 15:22:50 [Epoch 86] (475ms) Posterior free-energy 8.13302960e+07 = KL from prior 1.06838340e+04 - log-likelihood -8.13196160e+07
# 10/08/2021 15:22:50 [Epoch 87] (446ms) Posterior free-energy 8.13497200e+07 = KL from prior 1.07084248e+04 - log-likelihood -8.13390080e+07
# 10/08/2021 15:22:51 [Epoch 88] (425ms) Posterior free-energy 8.13071760e+07 = KL from prior 1.07057129e+04 - log-likelihood -8.12964720e+07
# 10/08/2021 15:22:51 [Epoch 89] (463ms) Posterior free-energy 8.13038880e+07 = KL from prior 1.07134072e+04 - log-likelihood -8.12931760e+07
# 10/08/2021 15:22:52 [Epoch 90] (486ms) Posterior free-energy 8.13082480e+07 = KL from prior 1.07328525e+04 - log-likelihood -8.12975120e+07
# 10/08/2021 15:22:52 [Epoch 91] (498ms) Posterior free-energy 8.12702320e+07 = KL from prior 1.07172959e+04 - log-likelihood -8.12595120e+07
# 10/08/2021 15:22:53 [Epoch 92] (481ms) Posterior free-energy 8.12815760e+07 = KL from prior 1.07134561e+04 - log-likelihood -8.12708640e+07
# 10/08/2021 15:22:53 [Epoch 93] (437ms) Posterior free-energy 8.12519680e+07 = KL from prior 1.06522490e+04 - log-likelihood -8.12413120e+07
# 10/08/2021 15:22:53 [Epoch 94] (442ms) Posterior free-energy 8.12501840e+07 = KL from prior 1.06565020e+04 - log-likelihood -8.12395280e+07
# 10/08/2021 15:22:54 [Epoch 95] (440ms) Posterior free-energy 8.12526800e+07 = KL from prior 1.06805674e+04 - log-likelihood -8.12420000e+07
# 10/08/2021 15:22:54 [Epoch 96] (486ms) Posterior free-energy 8.12556080e+07 = KL from prior 1.06408408e+04 - log-likelihood -8.12449680e+07
# 10/08/2021 15:22:55 [Epoch 97] (474ms) Posterior free-energy 8.12533280e+07 = KL from prior 1.06199541e+04 - log-likelihood -8.12427120e+07
# 10/08/2021 15:22:55 [Epoch 98] (419ms) Posterior free-energy 8.12253760e+07 = KL from prior 1.06129746e+04 - log-likelihood -8.12147600e+07
# 10/08/2021 15:22:56 [Epoch 99] (420ms) Posterior free-energy 8.12269520e+07 = KL from prior 1.06038018e+04 - log-likelihood -8.12163520e+07
# 10/08/2021 15:22:56 [Epoch 100] (472ms) Posterior free-energy 8.11984000e+07 = KL from prior 1.05872090e+04 - log-likelihood -8.11878160e+07
# 10/08/2021 15:22:57 [Epoch 101] (491ms) Posterior free-energy 8.12012000e+07 = KL from prior 1.05252852e+04 - log-likelihood -8.11906720e+07
# 10/08/2021 15:22:57 [Epoch 102] (462ms) Posterior free-energy 8.11798080e+07 = KL from prior 1.06055195e+04 - log-likelihood -8.11692000e+07
# 10/08/2021 15:22:58 [Epoch 103] (478ms) Posterior free-energy 8.11717360e+07 = KL from prior 1.06486982e+04 - log-likelihood -8.11610880e+07
# 10/08/2021 15:22:58 [Epoch 104] (492ms) Posterior free-energy 8.11575520e+07 = KL from prior 1.05192803e+04 - log-likelihood -8.11470320e+07
# 10/08/2021 15:22:59 [Epoch 105] (482ms) Posterior free-energy 8.11604640e+07 = KL from prior 1.04659336e+04 - log-likelihood -8.11500000e+07
# 10/08/2021 15:22:59 [Epoch 106] (487ms) Posterior free-energy 8.11631920e+07 = KL from prior 1.05290000e+04 - log-likelihood -8.11526640e+07
# 10/08/2021 15:23:00 [Epoch 107] (487ms) Posterior free-energy 8.11484240e+07 = KL from prior 1.04038828e+04 - log-likelihood -8.11380240e+07
# 10/08/2021 15:23:00 [Epoch 108] (638ms) Posterior free-energy 8.11474720e+07 = KL from prior 1.04297314e+04 - log-likelihood -8.11370400e+07
# 10/08/2021 15:23:01 [Epoch 109] (657ms) Posterior free-energy 8.11303840e+07 = KL from prior 1.04285732e+04 - log-likelihood -8.11199520e+07
# 10/08/2021 15:23:01 [Epoch 110] (540ms) Posterior free-energy 8.11025840e+07 = KL from prior 1.04646338e+04 - log-likelihood -8.10921200e+07
# 10/08/2021 15:23:02 [Epoch 111] (520ms) Posterior free-energy 8.11273760e+07 = KL from prior 1.04954902e+04 - log-likelihood -8.11168800e+07
# 10/08/2021 15:23:02 [Epoch 112] (494ms) Posterior free-energy 8.10992560e+07 = KL from prior 1.03673379e+04 - log-likelihood -8.10888880e+07
# 10/08/2021 15:23:03 [Epoch 113] (466ms) Posterior free-energy 8.10867120e+07 = KL from prior 1.03723438e+04 - log-likelihood -8.10763360e+07
# 10/08/2021 15:23:03 [Epoch 114] (427ms) Posterior free-energy 8.10862160e+07 = KL from prior 1.02854082e+04 - log-likelihood -8.10759280e+07
# 10/08/2021 15:23:04 [Epoch 115] (471ms) Posterior free-energy 8.10807280e+07 = KL from prior 1.04157480e+04 - log-likelihood -8.10703120e+07
# 10/08/2021 15:23:04 [Epoch 116] (481ms) Posterior free-energy 8.10742880e+07 = KL from prior 1.02582148e+04 - log-likelihood -8.10640320e+07
# 10/08/2021 15:23:05 [Epoch 117] (486ms) Posterior free-energy 8.10474320e+07 = KL from prior 1.02419111e+04 - log-likelihood -8.10371920e+07
# 10/08/2021 15:23:05 [Epoch 118] (448ms) Posterior free-energy 8.10512320e+07 = KL from prior 1.02298516e+04 - log-likelihood -8.10410000e+07
# 10/08/2021 15:23:06 [Epoch 119] (454ms) Posterior free-energy 8.10620720e+07 = KL from prior 1.00892852e+04 - log-likelihood -8.10519840e+07
# 10/08/2021 15:23:06 [Epoch 120] (482ms) Posterior free-energy 8.10406560e+07 = KL from prior 1.03030391e+04 - log-likelihood -8.10303520e+07
# 10/08/2021 15:23:07 [Epoch 121] (499ms) Posterior free-energy 8.10348480e+07 = KL from prior 1.00366123e+04 - log-likelihood -8.10248080e+07
# 10/08/2021 15:23:07 [Epoch 122] (479ms) Posterior free-energy 8.10268800e+07 = KL from prior 1.00038252e+04 - log-likelihood -8.10168800e+07
# 10/08/2021 15:23:08 [Epoch 123] (421ms) Posterior free-energy 8.10257920e+07 = KL from prior 9.97017383e+03 - log-likelihood -8.10158240e+07
# 10/08/2021 15:23:08 [Epoch 124] (444ms) Posterior free-energy 8.10054240e+07 = KL from prior 9.81515527e+03 - log-likelihood -8.09956080e+07
# 10/08/2021 15:23:08 [Epoch 125] (485ms) Posterior free-energy 8.09938640e+07 = KL from prior 9.81757031e+03 - log-likelihood -8.09840480e+07
# 10/08/2021 15:23:09 [Epoch 126] (443ms) Posterior free-energy 8.09994000e+07 = KL from prior 9.78522266e+03 - log-likelihood -8.09896160e+07
# 10/08/2021 15:23:09 [Epoch 127] (407ms) Posterior free-energy 8.09716400e+07 = KL from prior 9.76310156e+03 - log-likelihood -8.09618800e+07
# 10/08/2021 15:23:10 [Epoch 128] (418ms) Posterior free-energy 8.09818560e+07 = KL from prior 9.67569238e+03 - log-likelihood -8.09721840e+07
# 10/08/2021 15:23:10 [Epoch 129] (482ms) Posterior free-energy 8.09740560e+07 = KL from prior 9.48020312e+03 - log-likelihood -8.09645760e+07
# 10/08/2021 15:23:11 [Epoch 130] (499ms) Posterior free-energy 8.09639040e+07 = KL from prior 9.58932422e+03 - log-likelihood -8.09543120e+07
# 10/08/2021 15:23:11 [Epoch 131] (492ms) Posterior free-energy 8.09597760e+07 = KL from prior 9.58381641e+03 - log-likelihood -8.09501920e+07
# 10/08/2021 15:23:12 [Epoch 132] (471ms) Posterior free-energy 8.09628400e+07 = KL from prior 9.38458398e+03 - log-likelihood -8.09534560e+07
# 10/08/2021 15:23:12 [Epoch 133] (476ms) Posterior free-energy 8.09459600e+07 = KL from prior 9.35455957e+03 - log-likelihood -8.09366080e+07
# 10/08/2021 15:23:13 [Epoch 134] (472ms) Posterior free-energy 8.09416480e+07 = KL from prior 9.23502637e+03 - log-likelihood -8.09324160e+07
# 10/08/2021 15:23:13 [Epoch 135] (486ms) Posterior free-energy 8.09267840e+07 = KL from prior 9.18602344e+03 - log-likelihood -8.09176000e+07
# 10/08/2021 15:23:14 [Epoch 136] (470ms) Posterior free-energy 8.09302000e+07 = KL from prior 8.98466895e+03 - log-likelihood -8.09212160e+07
# 10/08/2021 15:23:14 [Epoch 137] (609ms) Posterior free-energy 8.09370400e+07 = KL from prior 8.96807031e+03 - log-likelihood -8.09280720e+07
# 10/08/2021 15:23:15 [Epoch 138] (661ms) Posterior free-energy 8.09168720e+07 = KL from prior 8.82078320e+03 - log-likelihood -8.09080480e+07
# 10/08/2021 15:23:15 [Epoch 139] (527ms) Posterior free-energy 8.09156880e+07 = KL from prior 8.69844531e+03 - log-likelihood -8.09069920e+07
# 10/08/2021 15:23:16 [Epoch 140] (493ms) Posterior free-energy 8.09205120e+07 = KL from prior 8.52438184e+03 - log-likelihood -8.09119840e+07
# 10/08/2021 15:23:16 [Epoch 141] (512ms) Posterior free-energy 8.08962960e+07 = KL from prior 8.46775391e+03 - log-likelihood -8.08878320e+07
# 10/08/2021 15:23:17 [Epoch 142] (535ms) Posterior free-energy 8.08952800e+07 = KL from prior 8.27395703e+03 - log-likelihood -8.08870080e+07
# 10/08/2021 15:23:17 [Epoch 143] (488ms) Posterior free-energy 8.08883440e+07 = KL from prior 8.57035059e+03 - log-likelihood -8.08797760e+07
# 10/08/2021 15:23:18 [Epoch 144] (457ms) Posterior free-energy 8.08826880e+07 = KL from prior 8.42653320e+03 - log-likelihood -8.08742640e+07
# 10/08/2021 15:23:18 [Epoch 145] (544ms) Posterior free-energy 8.08775920e+07 = KL from prior 8.35034473e+03 - log-likelihood -8.08692400e+07
# 10/08/2021 15:23:19 [Epoch 146] (463ms) Posterior free-energy 8.08750000e+07 = KL from prior 8.13734082e+03 - log-likelihood -8.08668640e+07
# 10/08/2021 15:23:19 [Epoch 147] (420ms) Posterior free-energy 8.08736800e+07 = KL from prior 7.98436279e+03 - log-likelihood -8.08656960e+07
# 10/08/2021 15:23:20 [Epoch 148] (418ms) Posterior free-energy 8.08664960e+07 = KL from prior 8.04275049e+03 - log-likelihood -8.08584560e+07
# 10/08/2021 15:23:20 [Epoch 149] (490ms) Posterior free-energy 8.08564640e+07 = KL from prior 8.04350049e+03 - log-likelihood -8.08484240e+07
# 10/08/2021 15:23:21 [Epoch 150] (490ms) Posterior free-energy 8.08553200e+07 = KL from prior 8.03679199e+03 - log-likelihood -8.08472800e+07
# 10/08/2021 15:23:21 [Epoch 151] (431ms) Posterior free-energy 8.08520720e+07 = KL from prior 8.03121338e+03 - log-likelihood -8.08440400e+07
# 10/08/2021 15:23:22 [Epoch 152] (425ms) Posterior free-energy 8.08495280e+07 = KL from prior 7.93467188e+03 - log-likelihood -8.08415920e+07
# 10/08/2021 15:23:22 [Epoch 153] (453ms) Posterior free-energy 8.08465200e+07 = KL from prior 7.87815576e+03 - log-likelihood -8.08386400e+07
# 10/08/2021 15:23:23 [Epoch 154] (497ms) Posterior free-energy 8.08429680e+07 = KL from prior 7.81237207e+03 - log-likelihood -8.08351520e+07
# 10/08/2021 15:23:23 [Epoch 155] (493ms) Posterior free-energy 8.08396880e+07 = KL from prior 7.87469141e+03 - log-likelihood -8.08318160e+07
# 10/08/2021 15:23:23 [Epoch 156] (429ms) Posterior free-energy 8.08386320e+07 = KL from prior 7.84160400e+03 - log-likelihood -8.08307920e+07
# 10/08/2021 15:23:24 [Epoch 157] (446ms) Posterior free-energy 8.08318400e+07 = KL from prior 7.67992383e+03 - log-likelihood -8.08241600e+07
# 10/08/2021 15:23:24 [Epoch 158] (490ms) Posterior free-energy 8.08278240e+07 = KL from prior 7.67009277e+03 - log-likelihood -8.08201520e+07
# 10/08/2021 15:23:25 [Epoch 159] (468ms) Posterior free-energy 8.08228880e+07 = KL from prior 7.62993408e+03 - log-likelihood -8.08152560e+07
# 10/08/2021 15:23:25 [Epoch 160] (484ms) Posterior free-energy 8.08247280e+07 = KL from prior 7.52370996e+03 - log-likelihood -8.08172080e+07
# 10/08/2021 15:23:26 [Epoch 161] (520ms) Posterior free-energy 8.08202000e+07 = KL from prior 7.50590576e+03 - log-likelihood -8.08126960e+07
# 10/08/2021 15:23:26 [Epoch 162] (456ms) Posterior free-energy 8.08149360e+07 = KL from prior 7.49984424e+03 - log-likelihood -8.08074400e+07
# 10/08/2021 15:23:27 [Epoch 163] (421ms) Posterior free-energy 8.08128560e+07 = KL from prior 7.43849316e+03 - log-likelihood -8.08054160e+07
# 10/08/2021 15:23:27 [Epoch 164] (470ms) Posterior free-energy 8.08134240e+07 = KL from prior 7.41935254e+03 - log-likelihood -8.08060080e+07
# 10/08/2021 15:23:28 [Epoch 165] (513ms) Posterior free-energy 8.08088880e+07 = KL from prior 7.33863525e+03 - log-likelihood -8.08015520e+07
# 10/08/2021 15:23:28 [Epoch 166] (496ms) Posterior free-energy 8.08099680e+07 = KL from prior 7.22772900e+03 - log-likelihood -8.08027440e+07
# 10/08/2021 15:23:29 [Epoch 167] (515ms) Posterior free-energy 8.08048640e+07 = KL from prior 7.11773047e+03 - log-likelihood -8.07977440e+07
# 10/08/2021 15:23:29 [Epoch 168] (482ms) Posterior free-energy 8.08042000e+07 = KL from prior 7.13517871e+03 - log-likelihood -8.07970640e+07
# 10/08/2021 15:23:30 [Epoch 169] (489ms) Posterior free-energy 8.08014720e+07 = KL from prior 7.06474756e+03 - log-likelihood -8.07944080e+07
# 10/08/2021 15:23:30 [Epoch 170] (461ms) Posterior free-energy 8.08014960e+07 = KL from prior 7.04227002e+03 - log-likelihood -8.07944560e+07
# 10/08/2021 15:23:31 [Epoch 171] (441ms) Posterior free-energy 8.07959600e+07 = KL from prior 7.06836475e+03 - log-likelihood -8.07888880e+07
# 10/08/2021 15:23:31 [Epoch 172] (524ms) Posterior free-energy 8.07919360e+07 = KL from prior 6.94354443e+03 - log-likelihood -8.07849920e+07
# 10/08/2021 15:23:32 [Epoch 173] (517ms) Posterior free-energy 8.07867440e+07 = KL from prior 6.87075781e+03 - log-likelihood -8.07798720e+07
# 10/08/2021 15:23:32 [Epoch 174] (502ms) Posterior free-energy 8.07870000e+07 = KL from prior 6.94950537e+03 - log-likelihood -8.07800480e+07
# 10/08/2021 15:23:33 [Epoch 175] (500ms) Posterior free-energy 8.07876480e+07 = KL from prior 6.82662891e+03 - log-likelihood -8.07808240e+07
# 10/08/2021 15:23:33 [Epoch 176] (511ms) Posterior free-energy 8.07822080e+07 = KL from prior 6.97618457e+03 - log-likelihood -8.07752320e+07
# 10/08/2021 15:23:34 [Epoch 177] (532ms) Posterior free-energy 8.07844480e+07 = KL from prior 6.82096826e+03 - log-likelihood -8.07776240e+07
# 10/08/2021 15:23:34 [Epoch 178] (486ms) Posterior free-energy 8.07846080e+07 = KL from prior 6.67426318e+03 - log-likelihood -8.07779360e+07
# 10/08/2021 15:23:35 [Epoch 179] (515ms) Posterior free-energy 8.07800960e+07 = KL from prior 6.89856299e+03 - log-likelihood -8.07732000e+07
# 10/08/2021 15:23:35 [Epoch 180] (482ms) Posterior free-energy 8.07788480e+07 = KL from prior 6.74710840e+03 - log-likelihood -8.07721040e+07
# 10/08/2021 15:23:36 [Epoch 181] (424ms) Posterior free-energy 8.07777600e+07 = KL from prior 6.64652734e+03 - log-likelihood -8.07711120e+07
# 10/08/2021 15:23:36 [Epoch 182] (506ms) Posterior free-energy 8.07774320e+07 = KL from prior 6.53094971e+03 - log-likelihood -8.07709040e+07
# 10/08/2021 15:23:37 [Epoch 183] (500ms) Posterior free-energy 8.07761440e+07 = KL from prior 6.61501758e+03 - log-likelihood -8.07695280e+07
# 10/08/2021 15:23:37 [Epoch 184] (456ms) Posterior free-energy 8.07773120e+07 = KL from prior 6.50565967e+03 - log-likelihood -8.07708080e+07
# 10/08/2021 15:23:38 [Epoch 185] (421ms) Posterior free-energy 8.07709600e+07 = KL from prior 6.65057178e+03 - log-likelihood -8.07643120e+07
# 10/08/2021 15:23:38 [Epoch 186] (474ms) Posterior free-energy 8.07727520e+07 = KL from prior 6.51119922e+03 - log-likelihood -8.07662400e+07
# 10/08/2021 15:23:39 [Epoch 187] (498ms) Posterior free-energy 8.07709200e+07 = KL from prior 6.53103662e+03 - log-likelihood -8.07643920e+07
# 10/08/2021 15:23:39 [Epoch 188] (494ms) Posterior free-energy 8.07698640e+07 = KL from prior 6.50038525e+03 - log-likelihood -8.07633600e+07
# 10/08/2021 15:23:40 [Epoch 189] (521ms) Posterior free-energy 8.07665840e+07 = KL from prior 6.45517188e+03 - log-likelihood -8.07601280e+07
# 10/08/2021 15:23:40 [Epoch 190] (474ms) Posterior free-energy 8.07661120e+07 = KL from prior 6.46700049e+03 - log-likelihood -8.07596480e+07
# 10/08/2021 15:23:40 [Epoch 191] (469ms) Posterior free-energy 8.07653120e+07 = KL from prior 6.53326367e+03 - log-likelihood -8.07587760e+07
# 10/08/2021 15:23:41 [Epoch 192] (521ms) Posterior free-energy 8.07649040e+07 = KL from prior 6.37094678e+03 - log-likelihood -8.07585360e+07
# 10/08/2021 15:23:41 [Epoch 193] (482ms) Posterior free-energy 8.07612160e+07 = KL from prior 6.49571875e+03 - log-likelihood -8.07547200e+07
# 10/08/2021 15:23:42 [Epoch 194] (671ms) Posterior free-energy 8.07621520e+07 = KL from prior 6.38254053e+03 - log-likelihood -8.07557680e+07
# 10/08/2021 15:23:43 [Epoch 195] (722ms) Posterior free-energy 8.07619200e+07 = KL from prior 6.35283154e+03 - log-likelihood -8.07555680e+07
# 10/08/2021 15:23:43 [Epoch 196] (542ms) Posterior free-energy 8.07609920e+07 = KL from prior 6.38478076e+03 - log-likelihood -8.07546080e+07
# 10/08/2021 15:23:44 [Epoch 197] (495ms) Posterior free-energy 8.07608800e+07 = KL from prior 6.22620459e+03 - log-likelihood -8.07546560e+07
# 10/08/2021 15:23:44 [Epoch 198] (470ms) Posterior free-energy 8.07584880e+07 = KL from prior 6.31921582e+03 - log-likelihood -8.07521680e+07
# 10/08/2021 15:23:45 [Epoch 199] (494ms) Posterior free-energy 8.07551840e+07 = KL from prior 6.40482275e+03 - log-likelihood -8.07487760e+07
# 10/08/2021 15:23:45 [Epoch 200] (420ms) Posterior free-energy 8.07568720e+07 = KL from prior 6.27112354e+03 - log-likelihood -8.07506000e+07
# 10/08/2021 15:23:46 [Epoch 201] (421ms) Posterior free-energy 8.07575920e+07 = KL from prior 6.32412549e+03 - log-likelihood -8.07512640e+07
# 10/08/2021 15:23:46 [Epoch 202] (476ms) Posterior free-energy 8.07561200e+07 = KL from prior 6.25145117e+03 - log-likelihood -8.07498720e+07
# 10/08/2021 15:23:47 [Epoch 203] (496ms) Posterior free-energy 8.07569200e+07 = KL from prior 6.31581592e+03 - log-likelihood -8.07506080e+07
# 10/08/2021 15:23:47 [Epoch 204] (494ms) Posterior free-energy 8.07533440e+07 = KL from prior 6.35481494e+03 - log-likelihood -8.07469920e+07
# 10/08/2021 15:23:48 [Epoch 205] (501ms) Posterior free-energy 8.07545200e+07 = KL from prior 6.30124414e+03 - log-likelihood -8.07482160e+07
# 10/08/2021 15:23:48 [Epoch 206] (502ms) Posterior free-energy 8.07527040e+07 = KL from prior 6.25415771e+03 - log-likelihood -8.07464480e+07
# 10/08/2021 15:23:49 [Epoch 207] (482ms) Posterior free-energy 8.07538640e+07 = KL from prior 6.10198975e+03 - log-likelihood -8.07477600e+07
# 10/08/2021 15:23:49 [Epoch 208] (441ms) Posterior free-energy 8.07539360e+07 = KL from prior 6.13929395e+03 - log-likelihood -8.07478000e+07
# 10/08/2021 15:23:50 [Epoch 209] (467ms) Posterior free-energy 8.07532400e+07 = KL from prior 6.12261572e+03 - log-likelihood -8.07471200e+07
# 10/08/2021 15:23:50 [Epoch 210] (494ms) Posterior free-energy 8.07508800e+07 = KL from prior 6.11327197e+03 - log-likelihood -8.07447680e+07
# 10/08/2021 15:23:51 [Epoch 211] (471ms) Posterior free-energy 8.07503200e+07 = KL from prior 6.15734326e+03 - log-likelihood -8.07441600e+07
# 10/08/2021 15:23:51 [Epoch 212] (502ms) Posterior free-energy 8.07497280e+07 = KL from prior 6.20848877e+03 - log-likelihood -8.07435200e+07
# 10/08/2021 15:23:52 [Epoch 213] (467ms) Posterior free-energy 8.07508000e+07 = KL from prior 6.14044971e+03 - log-likelihood -8.07446560e+07
# 10/08/2021 15:23:52 [Epoch 214] (468ms) Posterior free-energy 8.07479520e+07 = KL from prior 6.19602100e+03 - log-likelihood -8.07417520e+07
# 10/08/2021 15:23:53 [Epoch 215] (496ms) Posterior free-energy 8.07488400e+07 = KL from prior 6.31031641e+03 - log-likelihood -8.07425280e+07
# 10/08/2021 15:23:53 [Epoch 216] (493ms) Posterior free-energy 8.07463200e+07 = KL from prior 6.17518457e+03 - log-likelihood -8.07401440e+07
# 10/08/2021 15:23:54 [Epoch 217] (507ms) Posterior free-energy 8.07473520e+07 = KL from prior 6.01852393e+03 - log-likelihood -8.07413360e+07
# 10/08/2021 15:23:54 [Epoch 218] (456ms) Posterior free-energy 8.07477040e+07 = KL from prior 6.03413232e+03 - log-likelihood -8.07416720e+07
# 10/08/2021 15:23:54 [Epoch 219] (426ms) Posterior free-energy 8.07460560e+07 = KL from prior 6.02915771e+03 - log-likelihood -8.07400240e+07
# 10/08/2021 15:23:55 [Epoch 220] (430ms) Posterior free-energy 8.07454720e+07 = KL from prior 6.20794238e+03 - log-likelihood -8.07392640e+07
# 10/08/2021 15:23:55 [Epoch 221] (524ms) Posterior free-energy 8.07457280e+07 = KL from prior 6.18778906e+03 - log-likelihood -8.07395440e+07
# 10/08/2021 15:23:56 [Epoch 222] (512ms) Posterior free-energy 8.07449040e+07 = KL from prior 6.02095020e+03 - log-likelihood -8.07388800e+07
# 10/08/2021 15:23:56 [Epoch 223] (442ms) Posterior free-energy 8.07456000e+07 = KL from prior 6.09964990e+03 - log-likelihood -8.07395040e+07
# 10/08/2021 15:23:57 [Epoch 224] (432ms) Posterior free-energy 8.07439520e+07 = KL from prior 6.00982910e+03 - log-likelihood -8.07379440e+07
# 10/08/2021 15:23:57 [Epoch 225] (492ms) Posterior free-energy 8.07439280e+07 = KL from prior 5.96002441e+03 - log-likelihood -8.07379680e+07
# 10/08/2021 15:23:58 [Epoch 226] (515ms) Posterior free-energy 8.07427280e+07 = KL from prior 6.04469092e+03 - log-likelihood -8.07366800e+07
# 10/08/2021 15:23:58 [Epoch 227] (476ms) Posterior free-energy 8.07419360e+07 = KL from prior 5.99264355e+03 - log-likelihood -8.07359440e+07
# 10/08/2021 15:23:59 [Epoch 228] (485ms) Posterior free-energy 8.07420240e+07 = KL from prior 5.98844629e+03 - log-likelihood -8.07360320e+07
# 10/08/2021 15:23:59 [Epoch 229] (486ms) Posterior free-energy 8.07406720e+07 = KL from prior 6.07243311e+03 - log-likelihood -8.07346000e+07
# 10/08/2021 15:24:00 [Epoch 230] (486ms) Posterior free-energy 8.07424560e+07 = KL from prior 5.85582471e+03 - log-likelihood -8.07366000e+07
# 10/08/2021 15:24:00 [Epoch 231] (436ms) Posterior free-energy 8.07411200e+07 = KL from prior 5.97068701e+03 - log-likelihood -8.07351520e+07
# 10/08/2021 15:24:01 [Epoch 232] (478ms) Posterior free-energy 8.07420800e+07 = KL from prior 5.90493555e+03 - log-likelihood -8.07361760e+07
# 10/08/2021 15:24:01 [Epoch 233] (482ms) Posterior free-energy 8.07417360e+07 = KL from prior 5.88386523e+03 - log-likelihood -8.07358560e+07
# 10/08/2021 15:24:02 [Epoch 234] (482ms) Posterior free-energy 8.07409920e+07 = KL from prior 5.84442920e+03 - log-likelihood -8.07351440e+07
# 10/08/2021 15:24:02 [Epoch 235] (481ms) Posterior free-energy 8.07401920e+07 = KL from prior 5.90684619e+03 - log-likelihood -8.07342880e+07
# 10/08/2021 15:24:03 [Epoch 236] (490ms) Posterior free-energy 8.07400000e+07 = KL from prior 5.97116406e+03 - log-likelihood -8.07340320e+07
# 10/08/2021 15:24:03 [Epoch 237] (480ms) Posterior free-energy 8.07394320e+07 = KL from prior 5.93610400e+03 - log-likelihood -8.07334960e+07
# 10/08/2021 15:24:04 [Epoch 238] (474ms) Posterior free-energy 8.07397680e+07 = KL from prior 5.78674414e+03 - log-likelihood -8.07339840e+07
# 10/08/2021 15:24:04 [Epoch 239] (466ms) Posterior free-energy 8.07398560e+07 = KL from prior 5.77440283e+03 - log-likelihood -8.07340800e+07
# 10/08/2021 15:24:04 [Epoch 240] (478ms) Posterior free-energy 8.07393840e+07 = KL from prior 5.84626465e+03 - log-likelihood -8.07335360e+07
# 10/08/2021 15:24:05 [Epoch 241] (569ms) Posterior free-energy 8.07380080e+07 = KL from prior 5.97846582e+03 - log-likelihood -8.07320320e+07
# 10/08/2021 15:24:06 [Epoch 242] (676ms) Posterior free-energy 8.07385680e+07 = KL from prior 5.88190479e+03 - log-likelihood -8.07326880e+07
# 10/08/2021 15:24:06 [Epoch 243] (574ms) Posterior free-energy 8.07383600e+07 = KL from prior 5.94163086e+03 - log-likelihood -8.07324160e+07
# 10/08/2021 15:24:07 [Epoch 244] (541ms) Posterior free-energy 8.07401120e+07 = KL from prior 5.78991162e+03 - log-likelihood -8.07343200e+07
# 10/08/2021 15:24:07 [Epoch 245] (485ms) Posterior free-energy 8.07377840e+07 = KL from prior 5.87500146e+03 - log-likelihood -8.07319120e+07
# 10/08/2021 15:24:08 [Epoch 246] (485ms) Posterior free-energy 8.07380000e+07 = KL from prior 5.80824854e+03 - log-likelihood -8.07321920e+07
# 10/08/2021 15:24:08 [Epoch 247] (419ms) Posterior free-energy 8.07379680e+07 = KL from prior 5.80906250e+03 - log-likelihood -8.07321600e+07
# 10/08/2021 15:24:09 [Epoch 248] (445ms) Posterior free-energy 8.07388960e+07 = KL from prior 5.80949902e+03 - log-likelihood -8.07330880e+07
# 10/08/2021 15:24:09 [Epoch 249] (477ms) Posterior free-energy 8.07366880e+07 = KL from prior 5.82606445e+03 - log-likelihood -8.07308640e+07
# 10/08/2021 15:24:10 [Epoch 250] (485ms) Posterior free-energy 8.07380560e+07 = KL from prior 5.76265625e+03 - log-likelihood -8.07322960e+07
# 10/08/2021 15:24:10 [Epoch 251] (489ms) Posterior free-energy 8.07369760e+07 = KL from prior 5.79064795e+03 - log-likelihood -8.07311840e+07
# 10/08/2021 15:24:11 [Epoch 252] (488ms) Posterior free-energy 8.07365440e+07 = KL from prior 5.70443213e+03 - log-likelihood -8.07308400e+07
# 10/08/2021 15:24:11 [Epoch 253] (486ms) Posterior free-energy 8.07364560e+07 = KL from prior 5.87975977e+03 - log-likelihood -8.07305760e+07
# 10/08/2021 15:24:12 [Epoch 254] (569ms) Posterior free-energy 8.07358720e+07 = KL from prior 5.73111230e+03 - log-likelihood -8.07301440e+07
# 10/08/2021 15:24:12 [Epoch 255] (442ms) Posterior free-energy 8.07366960e+07 = KL from prior 5.73211475e+03 - log-likelihood -8.07309600e+07
# 10/08/2021 15:24:13 [Epoch 256] (432ms) Posterior free-energy 8.07363440e+07 = KL from prior 5.72999023e+03 - log-likelihood -8.07306160e+07
# 10/08/2021 15:24:13 [Epoch 257] (445ms) Posterior free-energy 8.07357920e+07 = KL from prior 5.70853467e+03 - log-likelihood -8.07300800e+07
# 10/08/2021 15:24:13 [Epoch 258] (475ms) Posterior free-energy 8.07349360e+07 = KL from prior 5.77644678e+03 - log-likelihood -8.07291600e+07
# 10/08/2021 15:24:14 [Epoch 259] (460ms) Posterior free-energy 8.07360080e+07 = KL from prior 5.83332471e+03 - log-likelihood -8.07301760e+07
# 10/08/2021 15:24:14 [Epoch 260] (422ms) Posterior free-energy 8.07366400e+07 = KL from prior 5.66873535e+03 - log-likelihood -8.07309680e+07
# 10/08/2021 15:24:15 [Epoch 261] (427ms) Posterior free-energy 8.07347200e+07 = KL from prior 5.73681787e+03 - log-likelihood -8.07289840e+07
# 10/08/2021 15:24:15 [Epoch 262] (568ms) Posterior free-energy 8.07365280e+07 = KL from prior 5.69000684e+03 - log-likelihood -8.07308400e+07
# 10/08/2021 15:24:16 [Epoch 263] (516ms) Posterior free-energy 8.07349200e+07 = KL from prior 5.73253662e+03 - log-likelihood -8.07291840e+07
# 10/08/2021 15:24:16 [Epoch 264] (504ms) Posterior free-energy 8.07355360e+07 = KL from prior 5.75124658e+03 - log-likelihood -8.07297840e+07
# 10/08/2021 15:24:17 [Epoch 265] (471ms) Posterior free-energy 8.07338480e+07 = KL from prior 5.73460107e+03 - log-likelihood -8.07281120e+07
# 10/08/2021 15:24:17 [Epoch 266] (393ms) Posterior free-energy 8.07341200e+07 = KL from prior 5.82118311e+03 - log-likelihood -8.07282960e+07
# 10/08/2021 15:24:18 [Epoch 267] (409ms) Posterior free-energy 8.07345840e+07 = KL from prior 5.76827002e+03 - log-likelihood -8.07288160e+07
# 10/08/2021 15:24:18 [Epoch 268] (449ms) Posterior free-energy 8.07343040e+07 = KL from prior 5.72702979e+03 - log-likelihood -8.07285760e+07
# 10/08/2021 15:24:19 [Epoch 269] (462ms) Posterior free-energy 8.07336160e+07 = KL from prior 5.74509863e+03 - log-likelihood -8.07278720e+07
# 10/08/2021 15:24:19 [Epoch 270] (474ms) Posterior free-energy 8.07328880e+07 = KL from prior 5.75659277e+03 - log-likelihood -8.07271280e+07
# 10/08/2021 15:24:20 [Epoch 271] (503ms) Posterior free-energy 8.07339360e+07 = KL from prior 5.75747607e+03 - log-likelihood -8.07281760e+07
# 10/08/2021 15:24:20 [Epoch 272] (494ms) Posterior free-energy 8.07330880e+07 = KL from prior 5.66320215e+03 - log-likelihood -8.07274240e+07
# 10/08/2021 15:24:21 [Epoch 273] (494ms) Posterior free-energy 8.07338080e+07 = KL from prior 5.67357520e+03 - log-likelihood -8.07281360e+07
# 10/08/2021 15:24:21 [Epoch 274] (496ms) Posterior free-energy 8.07334720e+07 = KL from prior 5.61824512e+03 - log-likelihood -8.07278560e+07
# 10/08/2021 15:24:22 [Epoch 275] (491ms) Posterior free-energy 8.07331920e+07 = KL from prior 5.71093701e+03 - log-likelihood -8.07274800e+07
# 10/08/2021 15:24:22 [Epoch 276] (613ms) Posterior free-energy 8.07330640e+07 = KL from prior 5.59428760e+03 - log-likelihood -8.07274720e+07
# 10/08/2021 15:24:23 [Epoch 277] (673ms) Posterior free-energy 8.07324960e+07 = KL from prior 5.68619043e+03 - log-likelihood -8.07268080e+07
# 10/08/2021 15:24:23 [Epoch 278] (530ms) Posterior free-energy 8.07315280e+07 = KL from prior 5.67215771e+03 - log-likelihood -8.07258560e+07
# 10/08/2021 15:24:24 [Epoch 279] (510ms) Posterior free-energy 8.07320400e+07 = KL from prior 5.63682520e+03 - log-likelihood -8.07264000e+07
# 10/08/2021 15:24:24 [Epoch 280] (476ms) Posterior free-energy 8.07324000e+07 = KL from prior 5.67450586e+03 - log-likelihood -8.07267280e+07
# 10/08/2021 15:24:25 [Epoch 281] (486ms) Posterior free-energy 8.07333600e+07 = KL from prior 5.56826172e+03 - log-likelihood -8.07277920e+07
# 10/08/2021 15:24:25 [Epoch 282] (401ms) Posterior free-energy 8.07318480e+07 = KL from prior 5.60066992e+03 - log-likelihood -8.07262480e+07
# 10/08/2021 15:24:26 [Epoch 283] (414ms) Posterior free-energy 8.07323440e+07 = KL from prior 5.65336426e+03 - log-likelihood -8.07266880e+07
# 10/08/2021 15:24:26 [Epoch 284] (465ms) Posterior free-energy 8.07326800e+07 = KL from prior 5.56609424e+03 - log-likelihood -8.07271120e+07
# 10/08/2021 15:24:27 [Epoch 285] (469ms) Posterior free-energy 8.07307120e+07 = KL from prior 5.72659082e+03 - log-likelihood -8.07249840e+07
# 10/08/2021 15:24:27 [Epoch 286] (463ms) Posterior free-energy 8.07316160e+07 = KL from prior 5.58615869e+03 - log-likelihood -8.07260320e+07
# 10/08/2021 15:24:28 [Epoch 287] (486ms) Posterior free-energy 8.07311680e+07 = KL from prior 5.68699707e+03 - log-likelihood -8.07254800e+07
# 10/08/2021 15:24:28 [Epoch 288] (479ms) Posterior free-energy 8.07316480e+07 = KL from prior 5.64398047e+03 - log-likelihood -8.07260080e+07
# 10/08/2021 15:24:28 [Epoch 289] (486ms) Posterior free-energy 8.07311120e+07 = KL from prior 5.62197803e+03 - log-likelihood -8.07254880e+07
# 10/08/2021 15:24:29 [Epoch 290] (491ms) Posterior free-energy 8.07314720e+07 = KL from prior 5.61045996e+03 - log-likelihood -8.07258640e+07
# 10/08/2021 15:24:30 [Epoch 291] (521ms) Posterior free-energy 8.07307920e+07 = KL from prior 5.64593799e+03 - log-likelihood -8.07251440e+07
# 10/08/2021 15:24:30 [Epoch 292] (612ms) Posterior free-energy 8.07300880e+07 = KL from prior 5.65038379e+03 - log-likelihood -8.07244400e+07
# 10/08/2021 15:24:31 [Epoch 293] (705ms) Posterior free-energy 8.07319360e+07 = KL from prior 5.62538379e+03 - log-likelihood -8.07263120e+07
# 10/08/2021 15:24:31 [Epoch 294] (553ms) Posterior free-energy 8.07312880e+07 = KL from prior 5.56106787e+03 - log-likelihood -8.07257280e+07
# 10/08/2021 15:24:32 [Epoch 295] (527ms) Posterior free-energy 8.07305200e+07 = KL from prior 5.59996436e+03 - log-likelihood -8.07249200e+07
# 10/08/2021 15:24:32 [Epoch 296] (502ms) Posterior free-energy 8.07304720e+07 = KL from prior 5.64341943e+03 - log-likelihood -8.07248320e+07
# 10/08/2021 15:24:33 [Epoch 297] (505ms) Posterior free-energy 8.07303120e+07 = KL from prior 5.53617480e+03 - log-likelihood -8.07247760e+07
# 10/08/2021 15:24:33 [Epoch 298] (551ms) Posterior free-energy 8.07303120e+07 = KL from prior 5.63493750e+03 - log-likelihood -8.07246800e+07
# 10/08/2021 15:24:34 [Epoch 299] (518ms) Posterior free-energy 8.07306480e+07 = KL from prior 5.57877832e+03 - log-likelihood -8.07250720e+07
# 10/08/2021 15:24:34 [Epoch 300] (477ms) Posterior free-energy 8.07299040e+07 = KL from prior 5.63633350e+03 - log-likelihood -8.07242640e+07
# 10/08/2021 15:24:35 [Epoch 301] (467ms) Posterior free-energy 8.07295440e+07 = KL from prior 5.66121387e+03 - log-likelihood -8.07238800e+07
# 10/08/2021 15:24:35 [Epoch 302] (446ms) Posterior free-energy 8.07296560e+07 = KL from prior 5.74127637e+03 - log-likelihood -8.07239120e+07
# 10/08/2021 15:24:36 [Epoch 303] (425ms) Posterior free-energy 8.07294960e+07 = KL from prior 5.61602490e+03 - log-likelihood -8.07238800e+07
# 10/08/2021 15:24:36 [Epoch 304] (480ms) Posterior free-energy 8.07292560e+07 = KL from prior 5.64023926e+03 - log-likelihood -8.07236160e+07
# 10/08/2021 15:24:37 [Epoch 305] (501ms) Posterior free-energy 8.07305120e+07 = KL from prior 5.55626318e+03 - log-likelihood -8.07249520e+07
# 10/08/2021 15:24:37 [Epoch 306] (494ms) Posterior free-energy 8.07298800e+07 = KL from prior 5.56454297e+03 - log-likelihood -8.07243120e+07
# 10/08/2021 15:24:38 [Epoch 307] (485ms) Posterior free-energy 8.07290080e+07 = KL from prior 5.59576367e+03 - log-likelihood -8.07234160e+07
# 10/08/2021 15:24:38 [Epoch 308] (485ms) Posterior free-energy 8.07288960e+07 = KL from prior 5.59442090e+03 - log-likelihood -8.07233040e+07
# 10/08/2021 15:24:39 [Epoch 309] (479ms) Posterior free-energy 8.07292960e+07 = KL from prior 5.60098828e+03 - log-likelihood -8.07236960e+07
# 10/08/2021 15:24:39 [Epoch 310] (478ms) Posterior free-energy 8.07280720e+07 = KL from prior 5.77599512e+03 - log-likelihood -8.07222960e+07
# 10/08/2021 15:24:40 [Epoch 311] (506ms) Posterior free-energy 8.07293040e+07 = KL from prior 5.63095166e+03 - log-likelihood -8.07236720e+07
# 10/08/2021 15:24:40 [Epoch 312] (435ms) Posterior free-energy 8.07288240e+07 = KL from prior 5.60370947e+03 - log-likelihood -8.07232240e+07
# 10/08/2021 15:24:41 [Epoch 313] (502ms) Posterior free-energy 8.07271760e+07 = KL from prior 5.69118115e+03 - log-likelihood -8.07214880e+07
# 10/08/2021 15:24:41 [Epoch 314] (451ms) Posterior free-energy 8.07287760e+07 = KL from prior 5.62441895e+03 - log-likelihood -8.07231520e+07
# 10/08/2021 15:24:42 [Epoch 315] (491ms) Posterior free-energy 8.07280560e+07 = KL from prior 5.65475928e+03 - log-likelihood -8.07224000e+07
# 10/08/2021 15:24:42 [Epoch 316] (492ms) Posterior free-energy 8.07281920e+07 = KL from prior 5.56472852e+03 - log-likelihood -8.07226240e+07
# Epoch   316: reducing learning rate of group 0 to 5.0000e-02.
# Epoch   316: reducing learning rate of group 1 to 5.0000e-04.
# Epoch   316: reducing learning rate of group 2 to 5.0000e-02.
# Epoch   316: reducing learning rate of group 3 to 5.0000e-04.
# 10/08/2021 15:24:43 [Epoch 317] (493ms) Posterior free-energy 8.07286240e+07 = KL from prior 5.57124609e+03 - log-likelihood -8.07230560e+07
# 10/08/2021 15:24:43 [Epoch 318] (483ms) Posterior free-energy 8.07279440e+07 = KL from prior 5.60303564e+03 - log-likelihood -8.07223440e+07
# 10/08/2021 15:24:44 [Epoch 319] (483ms) Posterior free-energy 8.07281360e+07 = KL from prior 5.54624756e+03 - log-likelihood -8.07225920e+07
# 10/08/2021 15:24:44 [Epoch 320] (491ms) Posterior free-energy 8.07282720e+07 = KL from prior 5.53550049e+03 - log-likelihood -8.07227360e+07
# 10/08/2021 15:24:45 [Epoch 321] (467ms) Posterior free-energy 8.07281360e+07 = KL from prior 5.53485400e+03 - log-likelihood -8.07226000e+07
# 10/08/2021 15:24:45 [Epoch 322] (566ms) Posterior free-energy 8.07282400e+07 = KL from prior 5.58080078e+03 - log-likelihood -8.07226560e+07
# 10/08/2021 15:24:46 [Epoch 323] (665ms) Posterior free-energy 8.07295040e+07 = KL from prior 5.47862988e+03 - log-likelihood -8.07240240e+07
# 10/08/2021 15:24:46 [Epoch 324] (537ms) Posterior free-energy 8.07279840e+07 = KL from prior 5.49217676e+03 - log-likelihood -8.07224880e+07
# 10/08/2021 15:24:47 [Epoch 325] (514ms) Posterior free-energy 8.07276240e+07 = KL from prior 5.50608838e+03 - log-likelihood -8.07221200e+07
# 10/08/2021 15:24:47 [Epoch 326] (453ms) Posterior free-energy 8.07280800e+07 = KL from prior 5.50708203e+03 - log-likelihood -8.07225760e+07
# 10/08/2021 15:24:48 [Epoch 327] (472ms) Posterior free-energy 8.07271280e+07 = KL from prior 5.54604883e+03 - log-likelihood -8.07215840e+07
# 10/08/2021 15:24:48 [Epoch 328] (418ms) Posterior free-energy 8.07280880e+07 = KL from prior 5.50287988e+03 - log-likelihood -8.07225840e+07
# 10/08/2021 15:24:49 [Epoch 329] (405ms) Posterior free-energy 8.07280480e+07 = KL from prior 5.51082373e+03 - log-likelihood -8.07225360e+07
# 10/08/2021 15:24:49 [Epoch 330] (431ms) Posterior free-energy 8.07278240e+07 = KL from prior 5.42699854e+03 - log-likelihood -8.07224000e+07
# 10/08/2021 15:24:50 [Epoch 331] (487ms) Posterior free-energy 8.07267440e+07 = KL from prior 5.51784961e+03 - log-likelihood -8.07212240e+07
# 10/08/2021 15:24:50 [Epoch 332] (540ms) Posterior free-energy 8.07276160e+07 = KL from prior 5.47391016e+03 - log-likelihood -8.07221440e+07
# 10/08/2021 15:24:51 [Epoch 333] (494ms) Posterior free-energy 8.07271520e+07 = KL from prior 5.51775830e+03 - log-likelihood -8.07216320e+07
# 10/08/2021 15:24:51 [Epoch 334] (505ms) Posterior free-energy 8.07274400e+07 = KL from prior 5.54796973e+03 - log-likelihood -8.07218960e+07
# 10/08/2021 15:24:52 [Epoch 335] (494ms) Posterior free-energy 8.07276000e+07 = KL from prior 5.49093506e+03 - log-likelihood -8.07221120e+07
# 10/08/2021 15:24:52 [Epoch 336] (427ms) Posterior free-energy 8.07272560e+07 = KL from prior 5.55648291e+03 - log-likelihood -8.07216960e+07
# 10/08/2021 15:24:52 [Epoch 337] (424ms) Posterior free-energy 8.07275120e+07 = KL from prior 5.59273828e+03 - log-likelihood -8.07219200e+07
# 10/08/2021 15:24:53 [Epoch 338] (395ms) Posterior free-energy 8.07261600e+07 = KL from prior 5.58351514e+03 - log-likelihood -8.07205760e+07
# 10/08/2021 15:24:53 [Epoch 339] (366ms) Posterior free-energy 8.07270720e+07 = KL from prior 5.55813867e+03 - log-likelihood -8.07215120e+07
# ...
# 10/08/2021 15:25:13 [Epoch 392] (299ms) Posterior free-energy 8.07255360e+07 = KL from prior 5.55322705e+03 - log-likelihood -8.07199840e+07
# 10/08/2021 15:25:13 [Epoch 393] (315ms) Posterior free-energy 8.07242000e+07 = KL from prior 5.57854150e+03 - log-likelihood -8.07186240e+07
# 10/08/2021 15:25:14 [Epoch 394] (314ms) Posterior free-energy 8.07253280e+07 = KL from prior 5.49296680e+03 - log-likelihood -8.07198320e+07
# 10/08/2021 15:25:14 [Epoch 395] (287ms) Posterior free-energy 8.07260560e+07 = KL from prior 5.42517676e+03 - log-likelihood -8.07206320e+07
# 10/08/2021 15:25:14 [Epoch 396] (261ms) Posterior free-energy 8.07244480e+07 = KL from prior 5.53603613e+03 - log-likelihood -8.07189120e+07
# 10/08/2021 15:25:15 [Epoch 397] (263ms) Posterior free-energy 8.07244800e+07 = KL from prior 5.60861768e+03 - log-likelihood -8.07188720e+07
# 10/08/2021 15:25:15 [Epoch 398] (261ms) Posterior free-energy 8.07250880e+07 = KL from prior 5.55291895e+03 - log-likelihood -8.07195360e+07
# 10/08/2021 15:25:15 [Epoch 399] (301ms) Posterior free-energy 8.07246640e+07 = KL from prior 5.56200830e+03 - log-likelihood -8.07191040e+07
# 10/08/2021 15:25:15 [Epoch 400] (315ms) Posterior free-energy 8.07246400e+07 = KL from prior 5.56331738e+03 - log-likelihood -8.07190800e+07
# 10/08/2021 15:25:16 [Epoch 401] (314ms) Posterior free-energy 8.07244000e+07 = KL from prior 5.62975439e+03 - log-likelihood -8.07187680e+07
# 10/08/2021 15:25:16 [Epoch 402] (285ms) Posterior free-energy 8.07246000e+07 = KL from prior 5.57798633e+03 - log-likelihood -8.07190240e+07
# 10/08/2021 15:25:16 [Epoch 403] (262ms) Posterior free-energy 8.07236640e+07 = KL from prior 5.64801318e+03 - log-likelihood -8.07180160e+07
# 10/08/2021 15:25:17 [Epoch 404] (262ms) Posterior free-energy 8.07252960e+07 = KL from prior 5.53417090e+03 - log-likelihood -8.07197600e+07
# 10/08/2021 15:25:17 [Epoch 405] (261ms) Posterior free-energy 8.07248320e+07 = KL from prior 5.57331787e+03 - log-likelihood -8.07192560e+07
# 10/08/2021 15:25:17 [Epoch 406] (302ms) Posterior free-energy 8.07243360e+07 = KL from prior 5.54972021e+03 - log-likelihood -8.07187840e+07
# 10/08/2021 15:25:17 [Epoch 407] (319ms) Posterior free-energy 8.07245440e+07 = KL from prior 5.51278320e+03 - log-likelihood -8.07190320e+07
# 10/08/2021 15:25:18 [Epoch 408] (318ms) Posterior free-energy 8.07239360e+07 = KL from prior 5.61379297e+03 - log-likelihood -8.07183200e+07
# 10/08/2021 15:25:18 [Epoch 409] (282ms) Posterior free-energy 8.07245760e+07 = KL from prior 5.53465430e+03 - log-likelihood -8.07190400e+07
# 10/08/2021 15:25:18 [Epoch 410] (262ms) Posterior free-energy 8.07251360e+07 = KL from prior 5.57142676e+03 - log-likelihood -8.07195680e+07
# 10/08/2021 15:25:19 [Epoch 411] (265ms) Posterior free-energy 8.07244000e+07 = KL from prior 5.50657812e+03 - log-likelihood -8.07188960e+07
# 10/08/2021 15:25:19 [Epoch 412] (262ms) Posterior free-energy 8.07235440e+07 = KL from prior 5.56503711e+03 - log-likelihood -8.07179760e+07
# 10/08/2021 15:25:19 [Epoch 413] (306ms) Posterior free-energy 8.07239040e+07 = KL from prior 5.53027881e+03 - log-likelihood -8.07183760e+07
# 10/08/2021 15:25:19 [Epoch 414] (315ms) Posterior free-energy 8.07248320e+07 = KL from prior 5.60048242e+03 - log-likelihood -8.07192320e+07
# 10/08/2021 15:25:20 [Epoch 415] (315ms) Posterior free-energy 8.07235360e+07 = KL from prior 5.58711279e+03 - log-likelihood -8.07179520e+07
# Epoch   415: reducing learning rate of group 0 to 2.5000e-02.
# Epoch   415: reducing learning rate of group 1 to 2.5000e-04.
# Epoch   415: reducing learning rate of group 2 to 2.5000e-02.
# Epoch   415: reducing learning rate of group 3 to 2.5000e-04.
# 10/08/2021 15:25:20 [Epoch 416] (281ms) Posterior free-energy 8.07238560e+07 = KL from prior 5.57306787e+03 - log-likelihood -8.07182800e+07
# 10/08/2021 15:25:20 [Epoch 417] (262ms) Posterior free-energy 8.07240880e+07 = KL from prior 5.58659473e+03 - log-likelihood -8.07185040e+07
# 10/08/2021 15:25:21 [Epoch 418] (262ms) Posterior free-energy 8.07241120e+07 = KL from prior 5.64097656e+03 - log-likelihood -8.07184720e+07
# 10/08/2021 15:25:21 [Epoch 419] (261ms) Posterior free-energy 8.07236080e+07 = KL from prior 5.60149707e+03 - log-likelihood -8.07180080e+07
# 10/08/2021 15:25:21 [Epoch 420] (307ms) Posterior free-energy 8.07235680e+07 = KL from prior 5.55129736e+03 - log-likelihood -8.07180160e+07
# 10/08/2021 15:25:21 [Epoch 421] (315ms) Posterior free-energy 8.07241360e+07 = KL from prior 5.63395410e+03 - log-likelihood -8.07185040e+07
# 10/08/2021 15:25:22 [Epoch 422] (315ms) Posterior free-energy 8.07238160e+07 = KL from prior 5.56525439e+03 - log-likelihood -8.07182480e+07
# 10/08/2021 15:25:22 [Epoch 423] (279ms) Posterior free-energy 8.07234880e+07 = KL from prior 5.57354053e+03 - log-likelihood -8.07179120e+07
# 10/08/2021 15:25:22 [Epoch 424] (262ms) Posterior free-energy 8.07234800e+07 = KL from prior 5.62500879e+03 - log-likelihood -8.07178560e+07
# 10/08/2021 15:25:23 [Epoch 425] (262ms) Posterior free-energy 8.07235760e+07 = KL from prior 5.61859570e+03 - log-likelihood -8.07179600e+07
# 10/08/2021 15:25:23 [Epoch 426] (262ms) Posterior free-energy 8.07235120e+07 = KL from prior 5.62411475e+03 - log-likelihood -8.07178880e+07
# 10/08/2021 15:25:23 [Epoch 427] (309ms) Posterior free-energy 8.07233520e+07 = KL from prior 5.55961133e+03 - log-likelihood -8.07177920e+07
# 10/08/2021 15:25:23 [Epoch 428] (315ms) Posterior free-energy 8.07234160e+07 = KL from prior 5.51608203e+03 - log-likelihood -8.07178960e+07
# 10/08/2021 15:25:24 [Epoch 429] (315ms) Posterior free-energy 8.07237920e+07 = KL from prior 5.60222607e+03 - log-likelihood -8.07181920e+07
# 10/08/2021 15:25:24 [Epoch 430] (277ms) Posterior free-energy 8.07239200e+07 = KL from prior 5.51017920e+03 - log-likelihood -8.07184080e+07
# 10/08/2021 15:25:24 [Epoch 431] (262ms) Posterior free-energy 8.07228880e+07 = KL from prior 5.61936914e+03 - log-likelihood -8.07172720e+07
# 10/08/2021 15:25:25 [Epoch 432] (263ms) Posterior free-energy 8.07236240e+07 = KL from prior 5.56150537e+03 - log-likelihood -8.07180640e+07
# 10/08/2021 15:25:25 [Epoch 433] (262ms) Posterior free-energy 8.07242480e+07 = KL from prior 5.52526465e+03 - log-likelihood -8.07187200e+07
# 10/08/2021 15:25:25 [Epoch 434] (311ms) Posterior free-energy 8.07234400e+07 = KL from prior 5.63761914e+03 - log-likelihood -8.07178000e+07
# 10/08/2021 15:25:26 [Epoch 435] (315ms) Posterior free-energy 8.07232000e+07 = KL from prior 5.64573682e+03 - log-likelihood -8.07175520e+07
# 10/08/2021 15:25:26 [Epoch 436] (315ms) Posterior free-energy 8.07232960e+07 = KL from prior 5.57377148e+03 - log-likelihood -8.07177200e+07
# 10/08/2021 15:25:26 [Epoch 437] (274ms) Posterior free-energy 8.07242720e+07 = KL from prior 5.52574219e+03 - log-likelihood -8.07187440e+07
# 10/08/2021 15:25:26 [Epoch 438] (262ms) Posterior free-energy 8.07226800e+07 = KL from prior 5.65695459e+03 - log-likelihood -8.07170240e+07
# 10/08/2021 15:25:27 [Epoch 439] (262ms) Posterior free-energy 8.07229600e+07 = KL from prior 5.57355273e+03 - log-likelihood -8.07173840e+07
# 10/08/2021 15:25:27 [Epoch 440] (262ms) Posterior free-energy 8.07236560e+07 = KL from prior 5.50270605e+03 - log-likelihood -8.07181520e+07
# 10/08/2021 15:25:27 [Epoch 441] (312ms) Posterior free-energy 8.07244320e+07 = KL from prior 5.52892676e+03 - log-likelihood -8.07189040e+07
# 10/08/2021 15:25:28 [Epoch 442] (315ms) Posterior free-energy 8.07240080e+07 = KL from prior 5.55286572e+03 - log-likelihood -8.07184560e+07
# 10/08/2021 15:25:28 [Epoch 443] (315ms) Posterior free-energy 8.07226880e+07 = KL from prior 5.61394287e+03 - log-likelihood -8.07170720e+07
# 10/08/2021 15:25:28 [Epoch 444] (273ms) Posterior free-energy 8.07241520e+07 = KL from prior 5.56258838e+03 - log-likelihood -8.07185920e+07
# 10/08/2021 15:25:28 [Epoch 445] (261ms) Posterior free-energy 8.07233520e+07 = KL from prior 5.53349609e+03 - log-likelihood -8.07178160e+07
# 10/08/2021 15:25:29 [Epoch 446] (262ms) Posterior free-energy 8.07243360e+07 = KL from prior 5.49477246e+03 - log-likelihood -8.07188400e+07
# 10/08/2021 15:25:29 [Epoch 447] (261ms) Posterior free-energy 8.07231600e+07 = KL from prior 5.62583691e+03 - log-likelihood -8.07175360e+07
# 10/08/2021 15:25:29 [Epoch 448] (314ms) Posterior free-energy 8.07233840e+07 = KL from prior 5.54583301e+03 - log-likelihood -8.07178400e+07
# 10/08/2021 15:25:30 [Epoch 449] (315ms) Posterior free-energy 8.07237360e+07 = KL from prior 5.52639600e+03 - log-likelihood -8.07182080e+07
# 10/08/2021 15:25:30 [Epoch 450] (315ms) Posterior free-energy 8.07231200e+07 = KL from prior 5.59337305e+03 - log-likelihood -8.07175280e+07
# 10/08/2021 15:25:30 [Epoch 451] (272ms) Posterior free-energy 8.07232400e+07 = KL from prior 5.59332324e+03 - log-likelihood -8.07176480e+07
# 10/08/2021 15:25:30 [Epoch 452] (262ms) Posterior free-energy 8.07234720e+07 = KL from prior 5.57671973e+03 - log-likelihood -8.07178960e+07
# 10/08/2021 15:25:31 [Epoch 453] (262ms) Posterior free-energy 8.07231600e+07 = KL from prior 5.60334912e+03 - log-likelihood -8.07175600e+07
# 10/08/2021 15:25:31 [Epoch 454] (261ms) Posterior free-energy 8.07232080e+07 = KL from prior 5.60799414e+03 - log-likelihood -8.07176000e+07
# 10/08/2021 15:25:31 [Epoch 455] (315ms) Posterior free-energy 8.07230880e+07 = KL from prior 5.54998438e+03 - log-likelihood -8.07175360e+07
# 10/08/2021 15:25:32 [Epoch 456] (315ms) Posterior free-energy 8.07234800e+07 = KL from prior 5.55626855e+03 - log-likelihood -8.07179200e+07
# 10/08/2021 15:25:32 [Epoch 457] (314ms) Posterior free-energy 8.07230240e+07 = KL from prior 5.62801465e+03 - log-likelihood -8.07173920e+07
# 10/08/2021 15:25:32 [Epoch 458] (270ms) Posterior free-energy 8.07233360e+07 = KL from prior 5.53700977e+03 - log-likelihood -8.07178000e+07
# 10/08/2021 15:25:32 [Epoch 459] (261ms) Posterior free-energy 8.07233680e+07 = KL from prior 5.51071973e+03 - log-likelihood -8.07178560e+07
# 10/08/2021 15:25:33 [Epoch 460] (262ms) Posterior free-energy 8.07244720e+07 = KL from prior 5.48771582e+03 - log-likelihood -8.07189840e+07
# 10/08/2021 15:25:33 [Epoch 461] (262ms) Posterior free-energy 8.07230320e+07 = KL from prior 5.57469922e+03 - log-likelihood -8.07174560e+07
# 10/08/2021 15:25:33 [Epoch 462] (315ms) Posterior free-energy 8.07226720e+07 = KL from prior 5.55932324e+03 - log-likelihood -8.07171120e+07
# 10/08/2021 15:25:34 [Epoch 463] (320ms) Posterior free-energy 8.07235920e+07 = KL from prior 5.58369629e+03 - log-likelihood -8.07180080e+07
# 10/08/2021 15:25:34 [Epoch 464] (315ms) Posterior free-energy 8.07231840e+07 = KL from prior 5.57616748e+03 - log-likelihood -8.07176080e+07
# 10/08/2021 15:25:34 [Epoch 465] (269ms) Posterior free-energy 8.07237280e+07 = KL from prior 5.52457617e+03 - log-likelihood -8.07182000e+07
# 10/08/2021 15:25:34 [Epoch 466] (261ms) Posterior free-energy 8.07224240e+07 = KL from prior 5.58406152e+03 - log-likelihood -8.07168400e+07
# Epoch   466: reducing learning rate of group 0 to 1.2500e-02.
# Epoch   466: reducing learning rate of group 1 to 1.2500e-04.
# Epoch   466: reducing learning rate of group 2 to 1.2500e-02.
# Epoch   466: reducing learning rate of group 3 to 1.2500e-04.
# 10/08/2021 15:25:35 [Epoch 467] (262ms) Posterior free-energy 8.07229040e+07 = KL from prior 5.60300391e+03 - log-likelihood -8.07173040e+07
# 10/08/2021 15:25:35 [Epoch 468] (269ms) Posterior free-energy 8.07235280e+07 = KL from prior 5.62969141e+03 - log-likelihood -8.07178960e+07
# 10/08/2021 15:25:35 [Epoch 469] (308ms) Posterior free-energy 8.07231920e+07 = KL from prior 5.58172705e+03 - log-likelihood -8.07176080e+07
# 10/08/2021 15:25:36 [Epoch 470] (319ms) Posterior free-energy 8.07232000e+07 = KL from prior 5.57206006e+03 - log-likelihood -8.07176240e+07
# 10/08/2021 15:25:36 [Epoch 471] (311ms) Posterior free-energy 8.07242160e+07 = KL from prior 5.48519629e+03 - log-likelihood -8.07187280e+07
# 10/08/2021 15:25:36 [Epoch 472] (271ms) Posterior free-energy 8.07227440e+07 = KL from prior 5.56378174e+03 - log-likelihood -8.07171840e+07
# 10/08/2021 15:25:36 [Epoch 473] (264ms) Posterior free-energy 8.07234800e+07 = KL from prior 5.51616846e+03 - log-likelihood -8.07179600e+07
# 10/08/2021 15:25:37 [Epoch 474] (256ms) Posterior free-energy 8.07226320e+07 = KL from prior 5.57429541e+03 - log-likelihood -8.07170560e+07
# 10/08/2021 15:25:37 [Epoch 475] (261ms) Posterior free-energy 8.07227040e+07 = KL from prior 5.58635107e+03 - log-likelihood -8.07171200e+07
# 10/08/2021 15:25:37 [Epoch 476] (227ms) Posterior free-energy 8.07229360e+07 = KL from prior 5.55759570e+03 - log-likelihood -8.07173760e+07
# 10/08/2021 15:25:37 [Epoch 477] (229ms) Posterior free-energy 8.07226560e+07 = KL from prior 5.60202930e+03 - log-likelihood -8.07170560e+07
# 10/08/2021 15:25:38 [Epoch 478] (236ms) Posterior free-energy 8.07237920e+07 = KL from prior 5.57120312e+03 - log-likelihood -8.07182240e+07
# 10/08/2021 15:25:38 [Epoch 479] (241ms) Posterior free-energy 8.07228240e+07 = KL from prior 5.56662744e+03 - log-likelihood -8.07172560e+07
# 10/08/2021 15:25:38 [Epoch 480] (266ms) Posterior free-energy 8.07232240e+07 = KL from prior 5.49082080e+03 - log-likelihood -8.07177360e+07
# 10/08/2021 15:25:38 [Epoch 481] (258ms) Posterior free-energy 8.07230240e+07 = KL from prior 5.59031641e+03 - log-likelihood -8.07174320e+07
# 10/08/2021 15:25:39 [Epoch 482] (283ms) Posterior free-energy 8.07224400e+07 = KL from prior 5.55557812e+03 - log-likelihood -8.07168880e+07
# 10/08/2021 15:25:39 [Epoch 483] (260ms) Posterior free-energy 8.07228720e+07 = KL from prior 5.52295117e+03 - log-likelihood -8.07173520e+07
# 10/08/2021 15:25:39 [Epoch 484] (275ms) Posterior free-energy 8.07237520e+07 = KL from prior 5.56156885e+03 - log-likelihood -8.07181920e+07
# 10/08/2021 15:25:39 [Epoch 485] (265ms) Posterior free-energy 8.07232080e+07 = KL from prior 5.53203662e+03 - log-likelihood -8.07176720e+07
# 10/08/2021 15:25:40 [Epoch 486] (265ms) Posterior free-energy 8.07230480e+07 = KL from prior 5.57318164e+03 - log-likelihood -8.07174720e+07
# 10/08/2021 15:25:40 [Epoch 487] (265ms) Posterior free-energy 8.07227840e+07 = KL from prior 5.51631396e+03 - log-likelihood -8.07172640e+07
# 10/08/2021 15:25:40 [Epoch 488] (257ms) Posterior free-energy 8.07232480e+07 = KL from prior 5.52415576e+03 - log-likelihood -8.07177200e+07
# 10/08/2021 15:25:41 [Epoch 489] (275ms) Posterior free-energy 8.07233920e+07 = KL from prior 5.60377246e+03 - log-likelihood -8.07177920e+07
# 10/08/2021 15:25:41 [Epoch 490] (265ms) Posterior free-energy 8.07230240e+07 = KL from prior 5.54345264e+03 - log-likelihood -8.07174800e+07
# 10/08/2021 15:25:41 [Epoch 491] (265ms) Posterior free-energy 8.07229120e+07 = KL from prior 5.55782129e+03 - log-likelihood -8.07173520e+07
# 10/08/2021 15:25:41 [Epoch 492] (257ms) Posterior free-energy 8.07227360e+07 = KL from prior 5.56021387e+03 - log-likelihood -8.07171760e+07
# 10/08/2021 15:25:42 [Epoch 493] (275ms) Posterior free-energy 8.07232000e+07 = KL from prior 5.54641846e+03 - log-likelihood -8.07176560e+07
# 10/08/2021 15:25:42 [Epoch 494] (265ms) Posterior free-energy 8.07225680e+07 = KL from prior 5.57437500e+03 - log-likelihood -8.07169920e+07
# 10/08/2021 15:25:42 [Epoch 495] (376ms) Posterior free-energy 8.07227600e+07 = KL from prior 5.56775439e+03 - log-likelihood -8.07171920e+07
# 10/08/2021 15:25:43 [Epoch 496] (391ms) Posterior free-energy 8.07224400e+07 = KL from prior 5.55241602e+03 - log-likelihood -8.07168880e+07
# 10/08/2021 15:25:43 [Epoch 497] (369ms) Posterior free-energy 8.07230240e+07 = KL from prior 5.55927832e+03 - log-likelihood -8.07174640e+07
# 10/08/2021 15:25:43 [Epoch 498] (312ms) Posterior free-energy 8.07231120e+07 = KL from prior 5.55777002e+03 - log-likelihood -8.07175520e+07
# 10/08/2021 15:25:44 [Epoch 499] (314ms) Posterior free-energy 8.07224480e+07 = KL from prior 5.59154395e+03 - log-likelihood -8.07168560e+07
# 10/08/2021 15:25:44 [Epoch 500] (305ms) Posterior free-energy 8.07226240e+07 = KL from prior 5.54840820e+03 - log-likelihood -8.07170720e+07
# 10/08/2021 15:25:44 Saving checkpoint...

# %%
if TRAIN:
    utils.plot_losses(losses)

# %%
def task_labeler(task):
    return task


def rest_task_labeler(task):
    if task == 'rest':
        return 'Rest'
    else:
        return 'Task'

# %%
def subject_labeler(subject):
    return str(subject)

# %%
hyperparams = dtfa.variational.hyperparams.state_vardict()
z_s_mu = hyperparams['task']['mu']
z_p_mu = hyperparams['subject_weight']['mu']
tasks = dtfa.tasks()
subjects = dtfa.subjects()
interactions = OrderedSet(list(itertools.product(subjects, tasks)))

# %%
subjects[0]
# Out:
# 1

# %%
dtfa.decoder.interaction_embedding(torch.cat((z_p_mu[1], z_s_mu[0]), dim=-1)).data.numpy()
# Out:
# array([-0.16010904, -0.14331613, -0.10984942, -0.23839997, -0.21254121,
#        -0.23712417, -0.14545093, -0.26106474], dtype=float32)

# %%
dtfa.decoder.interaction_embedding(torch.cat((z_p_mu[1], z_s_mu[1]), dim=-1))
# Out:
# tensor([-0.1907, -0.1110, -0.1386, -0.2211, -0.1862, -0.2149, -0.0580, -0.2648],
#        grad_fn=<PreluBackward>)

# %%
dtfa.decoder.interaction_embedding(torch.cat((z_p_mu[1], z_s_mu[2]), dim=-1))
# Out:
# tensor([-0.1270,  1.1742, -0.1991, -0.0943, -0.5237, -0.1092,  0.8258, -0.0818],
#        grad_fn=<PreluBackward>)

# %%
def stimulus_labeler(stimulus):
    stim = stimulus[-1]
    if int(stim) == 1 or int(stim) == 2:
        return 'State 0'
    elif int(stim) == 3 or int(stim) == 4:
        return 'State 1'
    elif int(stim) == 5 or int(stim) == 6:
        return 'State 2'
    elif int(stim) == 7 or int(stim) == 8:
        return 'State 3'
    else:
        print ('Error')

# %%
dtfa.scatter_subject_embedding(labeler=subject_labeler, figsize=None, colormap='Set1',
                            filename='subject_norest_subject_embedding' + scenario_name + '.png')
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch/htfa_torch/utils.py:149: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.scatter_subject_weight_embedding(labeler=subject_labeler, figsize=None, colormap='Set1',
                            filename='subject_norest_subject_weight_embedding' + scenario_name + '.png')
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch/htfa_torch/utils.py:149: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.scatter_task_embedding(labeler=stimulus_labeler,figsize=None, colormap='Set1',
                            filename='subject_norest_task_embedding' + scenario_name + '.png')
# Out:
# /home/zulqarnain/algorithm16_skipped/htfatorch/htfa_torch/utils.py:149: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def scatter_interactions_embedding(self, labeler=None, filename='', show=True,
                                   xlims=None, ylims=None, figsize=utils.FIGSIZE,
                                   colormap='Accent', serialize_data=True,
                                   plot_ellipse=True, legend_ordering=None,nstd=3):

    def eigsorted(cov):
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        return vals[order], vecs[:, order]
    
    if filename == '':
        filename = self.common_name() + '_task_embedding.pdf'
    hyperparams = self.variational.hyperparams.state_vardict()
    tasks = self.tasks()
    subjects = self.subjects()
    z_p_mu = hyperparams['subject_weight']['mu'].data
    z_s_mu = hyperparams['task']['mu'].data
    interactions = OrderedSet(list(itertools.product(subjects, tasks)))
    z_ps_mu = np.zeros(shape=(len(interactions),2))
    count = 0
    for p in range (len(subjects)):
        for t in range(len(tasks)):
            joint_embed = torch.cat((z_p_mu[p], z_s_mu[t]), dim=-1)
            interaction_embed = self.decoder.interaction_embedding(
                joint_embed).data
            z_ps_mu[count,:] = self.decoder.interaction_embedding_out(torch.cat((interaction_embed,
                                                                                 joint_embed),dim=-1)).data.numpy()
            count += 1
    embedding_name = 'z^{PS}'

    fig, ax = plt.subplots(facecolor='white', figsize=figsize, frameon=True)
    if xlims is not None:
        ax.set_xlim(xlims)
    if ylims is not None:
        ax.set_ylim(ylims)
    ax.set_xticks([])
    ax.set_yticks([])
    task_colors = ['black','darkgreen','red','blue']
    task_low_embeddings = []
    task_high_embeddings = []

    for i in range(len(z_ps_mu)):
        if stimulus_labeler(interactions[i][1]) == 'State 0':
            edgecolor = task_colors[0]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[0], marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[0], marker='^', s=400, linewidth=4)
            task_low_embeddings.append(z_ps_mu[i,:])
        elif stimulus_labeler(interactions[i][1]) == 'State 1':
            edgecolor = task_colors[1]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[1],marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[1],marker='^', s=400, linewidth=4)
            task_high_embeddings.append(z_ps_mu[i,:]) 
        elif stimulus_labeler(interactions[i][1]) == 'State 2':
            edgecolor = task_colors[2]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[2],marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[2],marker='^', s=400, linewidth=4)
            task_high_embeddings.append(z_ps_mu[i,:]) 
        elif stimulus_labeler(interactions[i][1]) == 'State 3':
            edgecolor = task_colors[3]
            if str(interactions[i][0]) == '1':
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[3],marker='o', s=400, linewidth=4)
            else:
                ax.scatter(z_ps_mu[i,0],z_ps_mu[i,1],facecolor='none', edgecolor=task_colors[3],marker='^', s=400, linewidth=4)
            task_high_embeddings.append(z_ps_mu[i,:]) 

    ordered_tasks = ['Baseline','Trial A', 'Trial B', 'Trial C']
    single_task_colors = ['darkgreen','red','blue']
    manual_legend = [mpatches.Patch(color=c,label=t) for (c,t) in zip(task_colors,ordered_tasks)]
    temp_dict = {key:[] for key in subjects}
    linestyle = ['solid','dashed']

    
    if filename is not None:
        fig.savefig(filename)
    if show:
        fig.show()
        
    return task_low_embeddings,task_high_embeddings

# %%
def interactions_labeler(subject,task):
    
    return task_labeler(task) + subject_labeler(subject)

# %%
task_low_embeddings,task_high_embeddings= scatter_interactions_embedding(dtfa,labeler=interactions_labeler,
                               filename='subject_norest_interaction_embedding' + scenario_name + '.png',
                               plot_ellipse=True,colormap='tab20',figsize=(5,5),nstd=3)
# Out:
# /home/zulqarnain/anaconda3/envs/htfatorch/lib/python3.7/site-packages/ipykernel_launcher.py:93: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
